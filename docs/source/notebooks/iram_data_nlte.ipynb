# %% [markdown]
# # IRAM Data Example
#
# Trey V. Wenger (c) December 2024
#
# Here we test `bayes_cn_hfs` on some real IRAM 30-m data and demonstrate a general procedure for determining the carbon isotopic ratio from observations of CN and 13CN.

# %%
# General imports   
import os
import pickle
import time

import matplotlib.pyplot as plt
import arviz as az
import pandas as pd
import numpy as np
import pymc as pm

print("pymc version:", pm.__version__)

import bayes_spec
print("bayes_spec version:", bayes_spec.__version__)

import bayes_cn_hfs
print("bayes_cn_hfs version:", bayes_cn_hfs.__version__)

# Notebook configuration
pd.options.display.max_rows = None
# Out:
# pymc version: 5.19.1
# bayes_spec version: 1.7.2
# bayes_cn_hfs version: 1.0.2+3.g8d34583.dirty

# %% [markdown]
# ## Load the data

# %%
from bayes_spec import SpecData
import pickle

with open("iram_data.pkl", "rb") as f:
    iram_data = pickle.load(f)

labels = ["12CN-1/2", "12CN-3/2", "13CN-1/2", "13CN-3/2"]
data = {
    label: SpecData(
        iram_data[f"frequency_{label}"][500:-500],
        iram_data[f"spectrum_{label}"][500:-500],
        iram_data[f"rms_{label}"],
        xlabel=r"LSRK Frequency (MHz)",
        ylabel=r"$T_A^*$ (K)",
    )
    for label in labels
}
data_12CN = {
    label: SpecData(
        iram_data[f"frequency_{label}"][500:-500],
        iram_data[f"spectrum_{label}"][500:-500],
        iram_data[f"rms_{label}"],
        xlabel=r"LSRK Frequency (MHz)",
        ylabel=r"$T_A^*$ (K)",
    )
    for label in labels if "12CN" in label
}
for label, dataset in data.items():
    print(label, len(dataset.spectral))

# Plot the data
fig, axes = plt.subplots(4, layout="constrained", figsize=(8, 12))
for i, label in enumerate(labels):
    axes[i].plot(data[label].spectral, data[label].brightness, 'k-')
    axes[i].set_xlabel(data[label].xlabel)
    axes[i].set_ylabel(data[label].ylabel)
# Out:
# 12CN-1/2 650
# 12CN-3/2 551
# 13CN-1/2 550
# 13CN-3/2 550

# %% [markdown]
# ## Assess LTE and Optical Depth
# First we explore the CN data to see if we can constrain the optical depth and non-LTE effects. These data do not have sufficient spectral resolution to constrain the thermal line width, and we expect there to be non-thermal broadening. We therefore fix the kinetic temperature. Hyperfine anomalies also appear to be present.

# %%
import importlib
from bayes_cn_hfs import cn_model
importlib.reload(cn_model)
from bayes_cn_hfs.cn_model import CNModel

# Initialize and define the model
n_clouds = 1
baseline_degree = 0
model = CNModel(
    data_12CN,
    bg_temp = 2.7, # assumed background temperature (K)
    Beff=0.78, # Main beam efficiency
    Feff=0.94, # Forward efficiency
    n_clouds=n_clouds,
    baseline_degree=baseline_degree,
    seed=1234,
    verbose=True
)
model.add_priors(
    prior_log10_N = [14.0, 1.0], 
    prior_velocity = [10.0, 10.0], # mean and width of velocity prior (km/s)
    prior_fwhm_nonthermal = 0.1, # width of non-thermal FWHM prior (km/s)
    prior_fwhm_L = 1.0, # width of latent Lorentzian FWHM prior (km/s)
    prior_rms = None, # do not infer spectral rms
    prior_baseline_coeffs = None, # default baseline priors
    fix_tau_total = None, # do not assume tau_total
    fix_log10_Tkin = None, # assume Tkin
    ordered = False, # do not assume optically-thin
)
model.add_likelihood()

# %%
from bayes_spec.plots import plot_predictive

# prior predictive check
prior = model.sample_prior_predictive(
    samples=100,  # prior predictive samples
)
_ = plot_predictive(model.data, prior.prior_predictive)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/conda/envs/bayes_cn_hfs-dev/lib/python3.12/site-packages/pytensor/compile/function/types.py:992, in Function.__call__(self, output_subset, *args, **kwargs)
#     991 try:
# --> 992     outputs = vm() if output_subset is None else vm(output_subset=output_subset)
#     993 except Exception:
#
# ValueError: Runtime broadcasting not allowed. One input had a distinct dimension length of 1, but was not marked as broadcastable: (input[%i].shape[%i] = %lld, input[%i].shape[%i] = %lld). If broadcasting was intended, use `specify_broadcastable` on the relevant input.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 4
#       1 from bayes_spec.plots import plot_predictive
#       3 # prior predictive check
# ----> 4 prior = model.sample_prior_predictive(
#       5     samples=100,  # prior predictive samples
#       6 )
#       7 _ = plot_predictive(model.data, prior.prior_predictive)
#
# File /opt/conda/envs/bayes_cn_hfs-dev/lib/python3.12/site-packages/bayes_spec/base_model.py:368, in BaseModel.sample_prior_predictive(self, samples)
#     360 """Generate prior predictive samples
#     361
#     362 :param samples: Number of prior predictive samples to draw, defaults to 50
#    (...)
#     365 :rtype: az.InferenceData
#     366 """
#     367 # validate
# --> 368 assert self._validate()
#     370 with self.model:
#     371     trace = pm.sample_prior_predictive(samples=samples, random_seed=self.seed)
#
# File /opt/conda/envs/bayes_cn_hfs-dev/lib/python3.12/site-packages/bayes_spec/base_model.py:218, in BaseModel._validate(self)
#     215     raise ValueError("No observed variables found! Did you add_likelihood()?")
#     217 # check that model can be evaluated
# --> 218 if not np.isfinite(self.model.logp().eval(self.model.initial_point())):
#     219     raise ValueError("Model initial point is not finite! Mis-specified model or bad priors?")
#     221 return True
#
# File /opt/conda/envs/bayes_cn_hfs-dev/lib/python3.12/site-packages/pytensor/graph/basic.py:662, in Variable.eval(self, inputs_to_values, **kwargs)
#     656         warnings.warn(
#     657             "Keyword arguments could not be used to create a cache key for the underlying variable. "
#     658             f"A function will be recompiled on every call with such keyword arguments.\n{exc}"
#     659         )
#     661 args = [parsed_inputs_to_values[param] for param in inputs]
# --> 662 return fn(*args)
#
# File /opt/conda/envs/bayes_cn_hfs-dev/lib/python3.12/site-packages/pytensor/compile/function/types.py:1002, in Function.__call__(self, output_subset, *args, **kwargs)
#    1000     if hasattr(self.vm, "thunks"):
#    1001         thunk = self.vm.thunks[self.vm.position_of_error]
# -> 1002     raise_with_op(
#    1003         self.maker.fgraph,
#    1004         node=self.vm.nodes[self.vm.position_of_error],
#    1005         thunk=thunk,
#    1006         storage_map=getattr(self.vm, "storage_map", None),
#    1007     )
#    1008 else:
#    1009     # old-style linkers raise their own exceptions
#    1010     raise
#
# File /opt/conda/envs/bayes_cn_hfs-dev/lib/python3.12/site-packages/pytensor/link/utils.py:526, in raise_with_op(fgraph, node, thunk, exc_info, storage_map)
#     521     warnings.warn(
#     522         f"{exc_type} error does not allow us to add an extra error message"
#     523     )
#     524     # Some exception need extra parameter in inputs. So forget the
#     525     # extra long error message in that case.
# --> 526 raise exc_value.with_traceback(exc_trace)
#
# File /opt/conda/envs/bayes_cn_hfs-dev/lib/python3.12/site-packages/pytensor/compile/function/types.py:992, in Function.__call__(self, output_subset, *args, **kwargs)
#     990     t0_fn = time.perf_counter()
#     991 try:
# --> 992     outputs = vm() if output_subset is None else vm(output_subset=output_subset)
#     993 except Exception:
#     994     self._restore_defaults()
#
# ValueError: Runtime broadcasting not allowed. One input had a distinct dimension length of 1, but was not marked as broadcastable: (input[%i].shape[%i] = %lld, input[%i].shape[%i] = %lld). If broadcasting was intended, use `specify_broadcastable` on the relevant input.
# Apply node that caused the error: Composite{...}([[[113109. ... 3377507]]], Mul.0, Composite{...}.3, Composite{...}.1, Composite{...}.9, Composite{...}.8, Composite{...}.7, ExpandDims{axis=0}.0, Sub.0, [[[3.54810 ... 338e-09]]], [[[1.13123 ... 422e+11]]], [[[5.42839 ... 3448211]]], [[[-7.4956 ... 276e-16]]], Log.0)
# Toposort index: 64
# Inputs types: [TensorType(float64, shape=(650, 1, 1)), TensorType(float64, shape=(1, 9, None)), TensorType(float64, shape=(1, 9, None)), TensorType(float64, shape=(1, 9, None)), TensorType(float64, shape=(1, 9, None)), TensorType(float64, shape=(1, 9, None)), TensorType(float64, shape=(1, 9, None)), TensorType(float64, shape=(1, 9, None)), TensorType(float64, shape=(1, 9, None)), TensorType(float64, shape=(1, 1, 9)), TensorType(float64, shape=(1, 1, 9)), TensorType(float64, shape=(650, 1, 1)), TensorType(float64, shape=(1, 9, 1)), TensorType(float64, shape=(1, 9, None))]
# Inputs shapes: [(650, 1, 1), (1, 9, 1), (1, 9, 1), (1, 9, 1), (1, 9, 1), (1, 9, 1), (1, 9, 1), (1, 9, 1), (1, 9, 1), (1, 1, 9), (1, 1, 9), (650, 1, 1), (1, 9, 1), (1, 9, 1)]
# Inputs strides: [(8, 0, 0), (72, 8, 8), (72, 8, 8), (72, 8, 8), (72, 8, 8), (72, 8, 8), (72, 8, 8), (72, 8, 8), (72, 8, 8), (72, 72, 8), (72, 72, 8), (8, 8, 8), (72, 8, 8), (72, 8, 8)]
# Inputs values: ['not shown', 'not shown', 'not shown', 'not shown', 'not shown', 'not shown', 'not shown', 'not shown', 'not shown', 'not shown', 'not shown', 'not shown', 'not shown', 'not shown']
# Outputs clients: [[Sum{axis=1}(Composite{...}.0)], [Sum{axis=1}(Composite{...}.1)]]
#
# HINT: Re-running with most PyTensor optimizations disabled could provide a back-trace showing when this node was created. This can be done by setting the PyTensor flag 'optimizer=fast_compile'. If that does not work, PyTensor optimizations can be disabled with 'optimizer=None'.
# HINT: Use the PyTensor flag `exception_verbosity=high` for a debug print-out and storage map footprint of this Apply node.

# %%
start = time.time()
model.fit(
    n = 100_000, # maximum number of VI iterations
    draws = 1_000, # number of posterior samples
    rel_tolerance = 0.01, # VI relative convergence threshold
    abs_tolerance = 0.1, # VI absolute convergence threshold
    learning_rate = 1e-2, # VI learning rate
)
end = time.time()
print(f"Runtime: {(end-start)/60.0:.2f} minutes")
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Convergence achieved at 3600
# Interrupted at 3,599 [3%]: Average Loss = 11,874
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Runtime: 0.61 minutes

# %%
pm.summary(model.trace.posterior)
# Out:
# arviz - WARNING - Shape validation failed: input_shape: (1, 1000), minimum_shape: (chains=2, draws=4)
#                                        mean     sd   hdi_3%  hdi_97%  \
# baseline_12CN-1/2_norm[0]            -0.301  0.007   -0.314   -0.288
# baseline_12CN-3/2_norm[0]            -0.297  0.005   -0.306   -0.289
# velocity_norm[0]                     -0.083  0.001   -0.085   -0.081
# log10_anomaly_norm[113123.3687, 0]    6.406  0.142    6.133    6.668
# log10_anomaly_norm[113144.19, 0]      1.143  0.056    1.045    1.255
# log10_anomaly_norm[113170.535, 0]     2.755  0.041    2.678    2.830
# log10_anomaly_norm[113191.325, 0]     1.021  0.044    0.946    1.107
# log10_anomaly_norm[113488.142, 0]     0.435  0.063    0.314    0.549
# log10_anomaly_norm[113490.985, 0]     1.130  0.025    1.082    1.177
# log10_anomaly_norm[113499.643, 0]    -0.134  0.081   -0.278    0.027
# log10_anomaly_norm[113508.934, 0]     1.871  0.049    1.771    1.953
# log10_anomaly_norm[113520.4215, 0]    4.276  0.246    3.818    4.745
# tau_total_norm[0]                     5.214  0.030    5.157    5.268
# fwhm_nonthermal_norm[0]               5.090  4.526    0.585   12.481
# fwhm_L_norm                           0.976  0.008    0.962    0.991
# tau_total[0]                          5.214  0.030    5.157    5.268
# velocity[0]                           9.166  0.010    9.148    9.188
# fwhm_thermal[0]                       0.236  0.000    0.236    0.236
# fwhm_nonthermal[0]                    0.509  0.453    0.059    1.248
# fwhm[0]                               0.581  0.426    0.238    1.263
# fwhm_L                                0.976  0.008    0.962    0.991
# log10_anomaly[113123.3687, 0]         0.641  0.014    0.613    0.667
# log10_anomaly[113144.19, 0]           0.114  0.006    0.104    0.126
# log10_anomaly[113170.535, 0]          0.276  0.004    0.268    0.283
# log10_anomaly[113191.325, 0]          0.102  0.004    0.095    0.111
# log10_anomaly[113488.142, 0]          0.044  0.006    0.031    0.055
# log10_anomaly[113490.985, 0]          0.113  0.003    0.108    0.118
# log10_anomaly[113499.643, 0]         -0.013  0.008   -0.028    0.003
# log10_anomaly[113508.934, 0]          0.187  0.005    0.177    0.195
# log10_anomaly[113520.4215, 0]         0.428  0.025    0.382    0.475
# Tex[113123.3687, 0]                 138.312  4.530  129.599  146.579
# Tex[113144.19, 0]                    41.152  0.534   40.212   42.208
# Tex[113170.535, 0]                   59.641  0.566   58.583   60.670
# Tex[113191.325, 0]                   40.006  0.407   39.322   40.800
# Tex[113488.142, 0]                   34.960  0.508   33.994   35.884
# Tex[113490.985, 0]                   41.020  0.238   40.572   41.466
# Tex[113499.643, 0]                   30.669  0.571   29.665   31.820
# Tex[113508.934, 0]                   48.650  0.551   47.548   49.584
# Tex[113520.4215, 0]                  84.789  4.813   76.168   94.307
#
#                                     mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# baseline_12CN-1/2_norm[0]               0.000    0.000     950.0     722.0
# baseline_12CN-3/2_norm[0]               0.000    0.000    1045.0     781.0
# velocity_norm[0]                        0.000    0.000     956.0     992.0
# log10_anomaly_norm[113123.3687, 0]      0.004    0.003    1022.0    1016.0
# log10_anomaly_norm[113144.19, 0]        0.002    0.001     762.0     847.0
# log10_anomaly_norm[113170.535, 0]       0.001    0.001     985.0     805.0
# log10_anomaly_norm[113191.325, 0]       0.001    0.001    1032.0     844.0
# log10_anomaly_norm[113488.142, 0]       0.002    0.001    1173.0     896.0
# log10_anomaly_norm[113490.985, 0]       0.001    0.001    1019.0    1013.0
# log10_anomaly_norm[113499.643, 0]       0.003    0.002     845.0    1026.0
# log10_anomaly_norm[113508.934, 0]       0.002    0.001     983.0     937.0
# log10_anomaly_norm[113520.4215, 0]      0.008    0.005    1042.0     982.0
# tau_total_norm[0]                       0.001    0.001    1043.0     958.0
# fwhm_nonthermal_norm[0]                 0.141    0.100     870.0     805.0
# fwhm_L_norm                             0.000    0.000     775.0     986.0
# tau_total[0]                            0.001    0.001    1043.0     958.0
# velocity[0]                             0.000    0.000     956.0     992.0
# fwhm_thermal[0]                         0.000    0.000    1000.0    1000.0
# fwhm_nonthermal[0]                      0.014    0.010     870.0     805.0
# fwhm[0]                                 0.013    0.009     870.0     805.0
# fwhm_L                                  0.000    0.000     775.0     986.0
# log10_anomaly[113123.3687, 0]           0.000    0.000    1022.0    1016.0
# log10_anomaly[113144.19, 0]             0.000    0.000     762.0     847.0
# log10_anomaly[113170.535, 0]            0.000    0.000     985.0     805.0
# log10_anomaly[113191.325, 0]            0.000    0.000    1032.0     844.0
# log10_anomaly[113488.142, 0]            0.000    0.000    1173.0     896.0
# log10_anomaly[113490.985, 0]            0.000    0.000    1019.0    1013.0
# log10_anomaly[113499.643, 0]            0.000    0.000     845.0    1026.0
# log10_anomaly[113508.934, 0]            0.000    0.000     983.0     937.0
# log10_anomaly[113520.4215, 0]           0.001    0.001    1042.0     982.0
# Tex[113123.3687, 0]                     0.142    0.100    1022.0    1016.0
# Tex[113144.19, 0]                       0.019    0.014     762.0     847.0
# Tex[113170.535, 0]                      0.018    0.013     985.0     805.0
# Tex[113191.325, 0]                      0.013    0.009    1032.0     844.0
# Tex[113488.142, 0]                      0.015    0.010    1173.0     896.0
# Tex[113490.985, 0]                      0.007    0.005    1019.0    1013.0
# Tex[113499.643, 0]                      0.020    0.014     845.0    1026.0
# Tex[113508.934, 0]                      0.018    0.012     983.0     937.0
# Tex[113520.4215, 0]                     0.149    0.106    1042.0     982.0
#
#                                     r_hat
# baseline_12CN-1/2_norm[0]             NaN
# baseline_12CN-3/2_norm[0]             NaN
# velocity_norm[0]                      NaN
# log10_anomaly_norm[113123.3687, 0]    NaN
# log10_anomaly_norm[113144.19, 0]      NaN
# log10_anomaly_norm[113170.535, 0]     NaN
# log10_anomaly_norm[113191.325, 0]     NaN
# log10_anomaly_norm[113488.142, 0]     NaN
# log10_anomaly_norm[113490.985, 0]     NaN
# log10_anomaly_norm[113499.643, 0]     NaN
# log10_anomaly_norm[113508.934, 0]     NaN
# log10_anomaly_norm[113520.4215, 0]    NaN
# tau_total_norm[0]                     NaN
# fwhm_nonthermal_norm[0]               NaN
# fwhm_L_norm                           NaN
# tau_total[0]                          NaN
# velocity[0]                           NaN
# fwhm_thermal[0]                       NaN
# fwhm_nonthermal[0]                    NaN
# fwhm[0]                               NaN
# fwhm_L                                NaN
# log10_anomaly[113123.3687, 0]         NaN
# log10_anomaly[113144.19, 0]           NaN
# log10_anomaly[113170.535, 0]          NaN
# log10_anomaly[113191.325, 0]          NaN
# log10_anomaly[113488.142, 0]          NaN
# log10_anomaly[113490.985, 0]          NaN
# log10_anomaly[113499.643, 0]          NaN
# log10_anomaly[113508.934, 0]          NaN
# log10_anomaly[113520.4215, 0]         NaN
# Tex[113123.3687, 0]                   NaN
# Tex[113144.19, 0]                     NaN
# Tex[113170.535, 0]                    NaN
# Tex[113191.325, 0]                    NaN
# Tex[113488.142, 0]                    NaN
# Tex[113490.985, 0]                    NaN
# Tex[113499.643, 0]                    NaN
# Tex[113508.934, 0]                    NaN
# Tex[113520.4215, 0]                   NaN

# %%
posterior = model.sample_posterior_predictive(
    thin=100, # keep one in {thin} posterior samples
)
_ = plot_predictive(model.data, posterior.posterior_predictive)
# Out:
# Sampling: [12CN-1/2, 12CN-3/2]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
start = time.time()
model.sample(
    init = "advi+adapt_diag", # initialization strategy
    tune = 1000, # tuning samples
    draws = 1000, # posterior samples
    chains = 8, # number of independent chains
    cores = 8, # number of parallel chains
    init_kwargs = {"rel_tolerance": 0.01, "abs_tolerance": 0.1, "learning_rate": 1e-2}, # VI initialization arguments
    nuts_kwargs = {"target_accept": 0.8}, # NUTS arguments
)
end = time.time()
print(f"Runtime: {(end-start)/60.0:.2f} minutes")
# Out:
# Initializing NUTS using custom advi+adapt_diag strategy
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Convergence achieved at 3600
# Interrupted at 3,599 [3%]: Average Loss = 11,874
# Multiprocess sampling (8 chains in 8 jobs)
# NUTS: [baseline_12CN-1/2_norm, baseline_12CN-3/2_norm, tau_total_norm, velocity_norm, fwhm_nonthermal_norm, fwhm_L_norm, log10_anomaly_norm]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 8 chains for 1_000 tune and 1_000 draw iterations (8_000 + 8_000 draws total) took 530 seconds.
# Adding log-likelihood to trace
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Runtime: 9.78 minutes

# %%
pm.summary(model.trace.posterior)
# Out:
# /opt/conda/envs/bayes_cn_hfs-dev/lib/python3.12/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
#                                       mean     sd  hdi_3%  hdi_97%  mcse_mean  \
# baseline_12CN-1/2_norm[0]           -0.286  0.006  -0.298   -0.274      0.000
# baseline_12CN-3/2_norm[0]           -0.290  0.004  -0.298   -0.282      0.000
# velocity_norm[0]                    -0.087  0.001  -0.088   -0.085      0.000
# log10_anomaly_norm[113123.3687, 0]   4.305  0.303   3.703    4.843      0.008
# log10_anomaly_norm[113144.19, 0]    -0.736  0.252  -1.209   -0.263      0.007
# log10_anomaly_norm[113170.535, 0]    0.817  0.262   0.315    1.293      0.007
# log10_anomaly_norm[113191.325, 0]   -0.838  0.247  -1.300   -0.375      0.007
# log10_anomaly_norm[113488.142, 0]   -1.247  0.246  -1.682   -0.762      0.007
# log10_anomaly_norm[113490.985, 0]   -0.592  0.226  -1.021   -0.172      0.006
# log10_anomaly_norm[113499.643, 0]   -1.931  0.245  -2.378   -1.459      0.007
# log10_anomaly_norm[113508.934, 0]   -0.028  0.257  -0.505    0.458      0.007
# log10_anomaly_norm[113520.4215, 0]   2.242  0.333   1.660    2.913      0.007
# tau_total_norm[0]                    8.065  0.532   7.108    9.112      0.015
# fwhm_nonthermal_norm[0]             19.472  0.661  18.289   20.750      0.010
# fwhm_L_norm                          0.744  0.018   0.710    0.777      0.000
# tau_total[0]                         8.065  0.532   7.108    9.112      0.015
# velocity[0]                          9.135  0.006   9.123    9.147      0.000
# fwhm_thermal[0]                      0.236  0.000   0.236    0.236      0.000
# fwhm_nonthermal[0]                   1.947  0.066   1.829    2.075      0.001
# fwhm[0]                              1.961  0.066   1.844    2.088      0.001
# fwhm_L                               0.744  0.018   0.710    0.777      0.000
# log10_anomaly[113123.3687, 0]        0.430  0.030   0.370    0.484      0.001
# log10_anomaly[113144.19, 0]         -0.074  0.025  -0.121   -0.026      0.001
# log10_anomaly[113170.535, 0]         0.082  0.026   0.031    0.129      0.001
# log10_anomaly[113191.325, 0]        -0.084  0.025  -0.130   -0.038      0.001
# log10_anomaly[113488.142, 0]        -0.125  0.025  -0.168   -0.076      0.001
# log10_anomaly[113490.985, 0]        -0.059  0.023  -0.102   -0.017      0.001
# log10_anomaly[113499.643, 0]        -0.193  0.024  -0.238   -0.146      0.001
# log10_anomaly[113508.934, 0]        -0.003  0.026  -0.050    0.046      0.001
# log10_anomaly[113520.4215, 0]        0.224  0.033   0.166    0.291      0.001
# Tex[113123.3687, 0]                 85.414  5.978  74.140   96.386      0.150
# Tex[113144.19, 0]                   26.736  1.558  23.937   29.764      0.042
# Tex[113170.535, 0]                  38.235  2.312  34.001   42.589      0.062
# Tex[113191.325, 0]                  26.119  1.493  23.443   29.004      0.041
# Tex[113488.142, 0]                  23.766  1.350  21.369   26.417      0.036
# Tex[113490.985, 0]                  27.631  1.444  24.974   30.367      0.040
# Tex[113499.643, 0]                  20.305  1.150  18.130   22.418      0.031
# Tex[113508.934, 0]                  31.475  1.871  27.930   34.889      0.050
# Tex[113520.4215, 0]                 53.146  4.094  45.684   60.975      0.092
#
#                                     mcse_sd  ess_bulk  ess_tail  r_hat
# baseline_12CN-1/2_norm[0]             0.000    7141.0    4732.0   1.00
# baseline_12CN-3/2_norm[0]             0.000    6736.0    5151.0   1.00
# velocity_norm[0]                      0.000    7443.0    5229.0   1.00
# log10_anomaly_norm[113123.3687, 0]    0.005    1605.0    2225.0   1.01
# log10_anomaly_norm[113144.19, 0]      0.005    1421.0    1992.0   1.01
# log10_anomaly_norm[113170.535, 0]     0.005    1398.0    1853.0   1.01
# log10_anomaly_norm[113191.325, 0]     0.005    1377.0    1782.0   1.01
# log10_anomaly_norm[113488.142, 0]     0.005    1361.0    1905.0   1.01
# log10_anomaly_norm[113490.985, 0]     0.004    1329.0    1780.0   1.01
# log10_anomaly_norm[113499.643, 0]     0.005    1379.0    1962.0   1.01
# log10_anomaly_norm[113508.934, 0]     0.005    1409.0    1887.0   1.01
# log10_anomaly_norm[113520.4215, 0]    0.005    2012.0    3054.0   1.00
# tau_total_norm[0]                     0.010    1331.0    1791.0   1.01
# fwhm_nonthermal_norm[0]               0.007    4806.0    5581.0   1.00
# fwhm_L_norm                           0.000    4174.0    4979.0   1.00
# tau_total[0]                          0.010    1331.0    1791.0   1.01
# velocity[0]                           0.000    7443.0    5229.0   1.00
# fwhm_thermal[0]                       0.000    8000.0    8000.0    NaN
# fwhm_nonthermal[0]                    0.001    4806.0    5581.0   1.00
# fwhm[0]                               0.001    4806.0    5581.0   1.00
# fwhm_L                                0.000    4174.0    4979.0   1.00
# log10_anomaly[113123.3687, 0]         0.001    1605.0    2225.0   1.01
# log10_anomaly[113144.19, 0]           0.000    1421.0    1992.0   1.01
# log10_anomaly[113170.535, 0]          0.000    1398.0    1853.0   1.01
# log10_anomaly[113191.325, 0]          0.000    1377.0    1782.0   1.01
# log10_anomaly[113488.142, 0]          0.000    1361.0    1905.0   1.01
# log10_anomaly[113490.985, 0]          0.000    1329.0    1780.0   1.01
# log10_anomaly[113499.643, 0]          0.000    1379.0    1962.0   1.01
# log10_anomaly[113508.934, 0]          0.000    1409.0    1887.0   1.01
# log10_anomaly[113520.4215, 0]         0.001    2012.0    3054.0   1.00
# Tex[113123.3687, 0]                   0.106    1605.0    2225.0   1.01
# Tex[113144.19, 0]                     0.030    1421.0    1992.0   1.01
# Tex[113170.535, 0]                    0.044    1398.0    1853.0   1.01
# Tex[113191.325, 0]                    0.029    1377.0    1782.0   1.01
# Tex[113488.142, 0]                    0.026    1361.0    1905.0   1.01
# Tex[113490.985, 0]                    0.028    1329.0    1780.0   1.01
# Tex[113499.643, 0]                    0.022    1379.0    1962.0   1.01
# Tex[113508.934, 0]                    0.036    1409.0    1887.0   1.01
# Tex[113520.4215, 0]                   0.065    2012.0    3054.0   1.00

# %%
posterior = model.sample_posterior_predictive(
    thin=100, # keep one in {thin} posterior samples
)
_ = plot_predictive(model.data, posterior.posterior_predictive)
# Out:
# Sampling: [12CN-1/2, 12CN-3/2]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ## Determine Number of Clouds
#
# The CN data has much greater signal-to-noise, so let's use those data to constrain the number of "cloud" components. We suspect that non-thermal broadening is important and we do not have sufficient spectral resolution to resolve the thermal line widths. We also suspect that hyperfine anomalies impact the CN data, so we use `HFSAnomalyModel`. For this degenerate model, we can't constrain the optical depth or kinetic temperature, so we assume the emission is optically thin.

# %%
from bayes_cn_hfs import get_molecule_data

mol_data_12CN = get_molecule_data(
    "CN, v = 0, 1", # molecule name in JPLSpec
    vibrational_state = 0, # vibrational state number
    rot_state_lower = 0, # lower rotational state
)
weight_12CN = 12.0 + 14.0

# %%
from bayes_cn_hfs import HFSAnomalyModel
from bayes_spec import Optimize

max_n_clouds = 5
baseline_degree = 0
opt = Optimize(
    HFSAnomalyModel,
    data_12CN,
    mol_weight=weight_12CN, # molecular weight
    mol_data=mol_data_12CN, # molecular data
    bg_temp = 2.7, # assumed background temperature (K)
    Beff = 1.0, # beam efficiency
    Feff = 1.0, # forward efficiency
    max_n_clouds=max_n_clouds,
    baseline_degree=baseline_degree,
    seed=1234,
    verbose=True
)
opt.add_priors(
    prior_velocity = [10.0, 5.0], # mean and width of velocity prior (km/s)
    prior_fwhm_nonthermal = 1.0, # width of non-thermal FWHM prior (km/s)
    prior_log10_anomaly = 0.1, # width of hyperfine anomaly prior (dex)
    prior_fwhm_L = 1.0, # width of latent Lorentzian FWHM prior (km/s)
    prior_rms = None, # do not infer spectral rms
    prior_baseline_coeffs = None, # default baseline priors
    fix_tau_total = 0.1, # fix tau_total
    fix_log10_Tkin = 1.5, # fix log10_Tkin
    ordered = False, # do not assume optically-thin
)
opt.add_likelihood()

# %%
fit_kwargs = {
    "rel_tolerance": 0.01,
    "abs_tolerance": 0.1,
    "learning_rate": 1e-2,
}
opt.fit_all(**fit_kwargs)
# Out:
# Null hypothesis BIC = 9.570e+04
# Approximating n_cloud = 1 posterior...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Convergence achieved at 7200
# Interrupted at 7,199 [7%]: Average Loss = 21,447
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# n_cloud = 1 BIC = -1.420e+02
#
# Approximating n_cloud = 2 posterior...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Convergence achieved at 17700
# Interrupted at 17,699 [17%]: Average Loss = 6,567.7
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# n_cloud = 2 BIC = -2.684e+03
#
# Approximating n_cloud = 3 posterior...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Convergence achieved at 15000
# Interrupted at 14,999 [14%]: Average Loss = 6,238.7
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# n_cloud = 3 BIC = -2.757e+03
#
# Approximating n_cloud = 4 posterior...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Convergence achieved at 28300
# Interrupted at 28,299 [28%]: Average Loss = 2,666.2
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# n_cloud = 4 BIC = -2.988e+03
#
# Approximating n_cloud = 5 posterior...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Convergence achieved at 31500
# Interrupted at 31,499 [31%]: Average Loss = 2,062.4
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# n_cloud = 5 BIC = -2.999e+03

# %%
n_clouds = np.arange(max_n_clouds + 1)
null_bic = opt.models[1].null_bic()
bics_vi = np.array([null_bic] + [model.bic(chain=0) for model in opt.models.values()])
for n_cloud, bic in zip(n_clouds, bics_vi):
    print(n_cloud, bic)
# Out:
# 0 95704.84851857378
# 1 -141.99916911614653
# 2 -2683.865918461791
# 3 -2756.788168882774
# 4 -2988.2105955864604
# 5 -2999.2679364407904

# %%
fig, ax = plt.subplots()
ax.plot(n_clouds[1:], bics_vi[1:], 'ko')
ax.set_xlabel("n_clouds")
_ = ax.set_ylabel("VI BIC")

# %% [markdown]
# The model with `n_clouds = 3` seems to be best. Let's compare with MCMC.

# %%
fit_kwargs = {
    "rel_tolerance": 0.01,
    "abs_tolerance": 0.1,
    "learning_rate": 1e-2,
}
sample_kwargs = {
    "chains": 8,
    "cores": 8,
    "init_kwargs": fit_kwargs,
    "nuts_kwargs": {"target_accept": 0.8},
}
opt.optimize(fit_kwargs=fit_kwargs, sample_kwargs=sample_kwargs, approx=False)
# Out:
# Null hypothesis BIC = 9.570e+04
# Sampling n_cloud = 1 posterior...
# Initializing NUTS using custom advi+adapt_diag strategy
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Convergence achieved at 7200
# Interrupted at 7,199 [7%]: Average Loss = 21,447
# Multiprocess sampling (8 chains in 8 jobs)
# NUTS: [baseline_12CN-1/2_norm, baseline_12CN-3/2_norm, velocity_norm, fwhm_nonthermal_norm, fwhm_L_norm, log10_anomaly_norm]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 8 chains for 1_000 tune and 1_000 draw iterations (8_000 + 8_000 draws total) took 123 seconds.
# Adding log-likelihood to trace
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# GMM converged to unique solution
# n_cloud = 1 solution = 0 BIC = -2.556e+03
#
# Sampling n_cloud = 2 posterior...
# Initializing NUTS using custom advi+adapt_diag strategy
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Convergence achieved at 17700
# Interrupted at 17,699 [17%]: Average Loss = 6,567.7
# Multiprocess sampling (8 chains in 8 jobs)
# NUTS: [baseline_12CN-1/2_norm, baseline_12CN-3/2_norm, velocity_norm, fwhm_nonthermal_norm, fwhm_L_norm, log10_anomaly_norm]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 8 chains for 1_000 tune and 1_000 draw iterations (8_000 + 8_000 draws total) took 299 seconds.
# Adding log-likelihood to trace
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# There were 817 divergences in converged chains.
# GMM converged to unique solution
# 6 of 8 chains appear converged.
# n_cloud = 2 solution = 0 BIC = -2.714e+03
#
# Sampling n_cloud = 3 posterior...
# Initializing NUTS using custom advi+adapt_diag strategy
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Convergence achieved at 15000
# Interrupted at 14,999 [14%]: Average Loss = 6,238.7
# Multiprocess sampling (8 chains in 8 jobs)
# NUTS: [baseline_12CN-1/2_norm, baseline_12CN-3/2_norm, velocity_norm, fwhm_nonthermal_norm, fwhm_L_norm, log10_anomaly_norm]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 8 chains for 1_000 tune and 1_000 draw iterations (8_000 + 8_000 draws total) took 358 seconds.
# Adding log-likelihood to trace
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# GMM found 2 unique solutions
# Solution 0: chains [0, 1, 2, 3, 6]
# Solution 1: chains [4, 5, 7]
# n_cloud = 3 solution = 0 BIC = -3.055e+03
# n_cloud = 3 solution = 1 BIC = -3.025e+03
#
# Sampling n_cloud = 4 posterior...
# Initializing NUTS using custom advi+adapt_diag strategy
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Convergence achieved at 28300
# Interrupted at 28,299 [28%]: Average Loss = 2,666.2
# Multiprocess sampling (8 chains in 8 jobs)
# NUTS: [baseline_12CN-1/2_norm, baseline_12CN-3/2_norm, velocity_norm, fwhm_nonthermal_norm, fwhm_L_norm, log10_anomaly_norm]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 8 chains for 1_000 tune and 1_000 draw iterations (8_000 + 8_000 draws total) took 336 seconds.
# Adding log-likelihood to trace
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# GMM converged to unique solution
# Label order mismatch in solution 0
# Chain 0 order: [3 1 0 2]
# Chain 1 order: [3 1 0 2]
# Chain 2 order: [3 1 0 2]
# Chain 3 order: [3 1 0 2]
# Chain 4 order: [3 1 0 2]
# Chain 5 order: [1 3 0 2]
# Chain 6 order: [3 1 0 2]
# Chain 7 order: [1 3 0 2]
# Adopting (first) most common order: [3 1 0 2]
# n_cloud = 4 solution = 0 BIC = -3.020e+03
#
# Sampling n_cloud = 5 posterior...
# Initializing NUTS using custom advi+adapt_diag strategy
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Convergence achieved at 31500
# Interrupted at 31,499 [31%]: Average Loss = 2,062.4
# Multiprocess sampling (8 chains in 8 jobs)
# NUTS: [baseline_12CN-1/2_norm, baseline_12CN-3/2_norm, velocity_norm, fwhm_nonthermal_norm, fwhm_L_norm, log10_anomaly_norm]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 8 chains for 1_000 tune and 1_000 draw iterations (8_000 + 8_000 draws total) took 600 seconds.
# Adding log-likelihood to trace
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# There were 66 divergences in converged chains.
# GMM converged to unique solution
# 4 of 8 chains appear converged.
# n_cloud = 5 solution = 0 BIC = -3.026e+03

# %%
null_bic_mcmc = opt.models[1].null_bic()
bics_mcmc = np.array([null_bic_mcmc] + [model.bic(solution=0) for model in opt.models.values()])
for n_cloud, bic in zip(n_clouds, bics_mcmc):
    print(n_cloud, bic)
# Out:
# 0 95704.84851857378
# 1 -2556.211385169106
# 2 -2713.923079495722
# 3 -3054.6369604886327
# 4 -3019.544281517717
# 5 -3025.732097556311

# %%
fig, ax = plt.subplots()
ax.plot(n_clouds[1:], bics_vi[1:], 'ko', label="VI")
ax.plot(n_clouds[1:], bics_mcmc[1:], 'ro', label="MCMC")
ax.set_xlabel("n_clouds")
ax.legend(loc="best")
_ = ax.set_ylabel("BIC")

# %%
from bayes_spec.plots import plot_predictive

posterior = opt.best_model.sample_posterior_predictive(
    thin=100, # keep one in {thin} posterior samples
)
_ = plot_predictive(opt.best_model.data, posterior.posterior_predictive)
# Out:
# Sampling: [12CN-1/2, 12CN-3/2]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
print(f"Best model has n_clouds={opt.best_model.n_clouds}")
print(f"Best model has solutions={opt.best_model.solutions}")
pm.summary(opt.best_model.trace.solution_0)
# Out:
# Best model has n_clouds=3
# Best model has solutions=[0, 1]
# /opt/conda/envs/bayes_cn_hfs-dev/lib/python3.12/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
#                                         mean       sd    hdi_3%   hdi_97%  \
# baseline_12CN-1/2_norm[0]             -0.250    0.007    -0.262    -0.238
# baseline_12CN-3/2_norm[0]             -0.249    0.004    -0.257    -0.241
# velocity_norm[0]                      -0.216    0.003    -0.222    -0.210
# velocity_norm[1]                      -0.838    0.022    -0.880    -0.798
# velocity_norm[2]                      -0.158    0.002    -0.161    -0.154
# log10_anomaly_norm[113123.3687, 0]    21.047    0.155    20.732    21.321
# log10_anomaly_norm[113123.3687, 1]     0.043    1.021    -1.926     1.914
# log10_anomaly_norm[113123.3687, 2]     0.165    0.998    -1.711     1.997
# log10_anomaly_norm[113144.19, 0]       0.261    1.028    -1.679     2.180
# log10_anomaly_norm[113144.19, 1]       1.505    0.969    -0.317     3.258
# log10_anomaly_norm[113144.19, 2]      16.013    0.078    15.866    16.157
# log10_anomaly_norm[113170.535, 0]      1.146    1.157    -0.931     3.304
# log10_anomaly_norm[113170.535, 1]      2.718    0.973     0.797     4.437
# log10_anomaly_norm[113170.535, 2]     17.808    0.065    17.689    17.933
# log10_anomaly_norm[113191.325, 0]      0.043    1.007    -1.801     1.943
# log10_anomaly_norm[113191.325, 1]      2.035    0.898     0.229     3.596
# log10_anomaly_norm[113191.325, 2]     15.880    0.071    15.739    16.004
# log10_anomaly_norm[113488.142, 0]     15.427    0.075    15.293    15.571
# log10_anomaly_norm[113488.142, 1]      2.380    1.090     0.307     4.405
# log10_anomaly_norm[113488.142, 2]     -0.082    0.981    -1.951     1.691
# log10_anomaly_norm[113490.985, 0]     -0.051    0.977    -1.897     1.732
# log10_anomaly_norm[113490.985, 1]      5.040    0.373     4.337     5.752
# log10_anomaly_norm[113490.985, 2]     15.851    0.055    15.749    15.957
# log10_anomaly_norm[113499.643, 0]     13.972    0.139    13.711    14.228
# log10_anomaly_norm[113499.643, 1]      2.187    1.028     0.267     4.068
# log10_anomaly_norm[113499.643, 2]      1.723    1.296    -0.694     4.223
# log10_anomaly_norm[113508.934, 0]      0.275    1.041    -1.656     2.248
# log10_anomaly_norm[113508.934, 1]      0.985    0.973    -0.823     2.779
# log10_anomaly_norm[113508.934, 2]     16.842    0.074    16.700    16.975
# log10_anomaly_norm[113520.4215, 0]     1.408    1.252    -0.786     3.849
# log10_anomaly_norm[113520.4215, 1]     0.218    1.002    -1.574     2.237
# log10_anomaly_norm[113520.4215, 2]     1.234    1.157    -1.024     3.257
# fwhm_nonthermal_norm[0]                2.382    0.061     2.271     2.500
# fwhm_nonthermal_norm[1]                2.413    0.230     1.981     2.838
# fwhm_nonthermal_norm[2]                3.084    0.035     3.019     3.150
# fwhm_L_norm                            0.263    0.028     0.209     0.313
# velocity[0]                            8.922    0.017     8.890     8.951
# velocity[1]                            5.812    0.109     5.602     6.012
# velocity[2]                            9.210    0.010     9.193     9.228
# fwhm_thermal[0]                        0.236    0.000     0.236     0.236
# fwhm_thermal[1]                        0.236    0.000     0.236     0.236
# fwhm_thermal[2]                        0.236    0.000     0.236     0.236
# fwhm_nonthermal[0]                     2.382    0.061     2.271     2.500
# fwhm_nonthermal[1]                     2.413    0.230     1.981     2.838
# fwhm_nonthermal[2]                     3.084    0.035     3.019     3.150
# fwhm[0]                                2.394    0.061     2.283     2.511
# fwhm[1]                                2.425    0.229     1.995     2.848
# fwhm[2]                                3.093    0.035     3.028     3.159
# fwhm_L                                 0.263    0.028     0.209     0.313
# log10_anomaly[113123.3687, 0]          2.105    0.016     2.073     2.132
# log10_anomaly[113123.3687, 1]          0.004    0.102    -0.193     0.191
# log10_anomaly[113123.3687, 2]          0.016    0.100    -0.171     0.200
# log10_anomaly[113144.19, 0]            0.026    0.103    -0.168     0.218
# log10_anomaly[113144.19, 1]            0.151    0.097    -0.032     0.326
# log10_anomaly[113144.19, 2]            1.601    0.008     1.587     1.616
# log10_anomaly[113170.535, 0]           0.115    0.116    -0.093     0.330
# log10_anomaly[113170.535, 1]           0.272    0.097     0.080     0.444
# log10_anomaly[113170.535, 2]           1.781    0.007     1.769     1.793
# log10_anomaly[113191.325, 0]           0.004    0.101    -0.180     0.194
# log10_anomaly[113191.325, 1]           0.204    0.090     0.023     0.360
# log10_anomaly[113191.325, 2]           1.588    0.007     1.574     1.600
# log10_anomaly[113488.142, 0]           1.543    0.007     1.529     1.557
# log10_anomaly[113488.142, 1]           0.238    0.109     0.031     0.440
# log10_anomaly[113488.142, 2]          -0.008    0.098    -0.195     0.169
# log10_anomaly[113490.985, 0]          -0.005    0.098    -0.190     0.173
# log10_anomaly[113490.985, 1]           0.504    0.037     0.434     0.575
# log10_anomaly[113490.985, 2]           1.585    0.006     1.575     1.596
# log10_anomaly[113499.643, 0]           1.397    0.014     1.371     1.423
# log10_anomaly[113499.643, 1]           0.219    0.103     0.027     0.407
# log10_anomaly[113499.643, 2]           0.172    0.130    -0.069     0.422
# log10_anomaly[113508.934, 0]           0.027    0.104    -0.166     0.225
# log10_anomaly[113508.934, 1]           0.098    0.097    -0.082     0.278
# log10_anomaly[113508.934, 2]           1.684    0.007     1.670     1.697
# log10_anomaly[113520.4215, 0]          0.141    0.125    -0.079     0.385
# log10_anomaly[113520.4215, 1]          0.022    0.100    -0.157     0.224
# log10_anomaly[113520.4215, 2]          0.123    0.116    -0.102     0.326
# Tex[113123.3687, 0]                 4027.229  143.930  3742.455  4286.206
# Tex[113123.3687, 1]                   32.835    7.845    19.340    47.628
# Tex[113123.3687, 2]                   33.725    7.868    20.650    48.882
# Tex[113144.19, 0]                     34.537    8.307    20.272    50.109
# Tex[113144.19, 1]                     45.831   10.126    27.817    64.692
# Tex[113144.19, 2]                   1262.760   22.767  1220.537  1305.387
# Tex[113170.535, 0]                    42.667   11.632    22.649    63.353
# Tex[113170.535, 1]                    60.599   13.334    36.007    85.069
# Tex[113170.535, 2]                  1908.980   28.711  1854.578  1961.632
# Tex[113191.325, 0]                    32.809    7.732    19.205    46.863
# Tex[113191.325, 1]                    51.600   10.519    32.588    71.438
# Tex[113191.325, 2]                  1224.784   20.072  1185.575  1260.025
# Tex[113488.142, 0]                  1103.386   19.028  1069.773  1140.436
# Tex[113488.142, 1]                    56.426   14.131    31.219    83.636
# Tex[113488.142, 2]                    31.833    7.254    19.472    45.583
# Tex[113490.985, 0]                    32.049    7.224    19.781    46.071
# Tex[113490.985, 1]                   101.300    8.696    85.097   118.076
# Tex[113490.985, 2]                  1216.624   15.510  1186.432  1244.732
# Tex[113499.643, 0]                   789.708   25.065   741.901   835.614
# Tex[113499.643, 1]                    53.782   12.532    31.355    77.216
# Tex[113499.643, 2]                    49.232   15.893    23.282    77.522
# Tex[113508.934, 0]                    34.674    8.482    20.126    50.595
# Tex[113508.934, 1]                    40.671    9.109    24.738    57.967
# Tex[113508.934, 2]                  1528.376   25.857  1479.243  1575.706
# Tex[113520.4215, 0]                   45.617   13.707    24.255    71.905
# Tex[113520.4215, 1]                   34.146    8.007    19.598    48.851
# Tex[113520.4215, 2]                   43.556   12.125    24.551    66.398
#
#                                     mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# baseline_12CN-1/2_norm[0]               0.000    0.000    5842.0    3479.0
# baseline_12CN-3/2_norm[0]               0.000    0.000    5357.0    4057.0
# velocity_norm[0]                        0.000    0.000    8967.0    4067.0
# velocity_norm[1]                        0.000    0.000    4035.0    3850.0
# velocity_norm[2]                        0.000    0.000    3722.0    3187.0
# log10_anomaly_norm[113123.3687, 0]      0.002    0.001    5774.0    3774.0
# log10_anomaly_norm[113123.3687, 1]      0.010    0.017   11088.0    3436.0
# log10_anomaly_norm[113123.3687, 2]      0.009    0.015   11224.0    3954.0
# log10_anomaly_norm[113144.19, 0]        0.011    0.015    8560.0    4122.0
# log10_anomaly_norm[113144.19, 1]        0.010    0.008   10018.0    3812.0
# log10_anomaly_norm[113144.19, 2]        0.001    0.001    3170.0    3961.0
# log10_anomaly_norm[113170.535, 0]       0.013    0.014    8239.0    3755.0
# log10_anomaly_norm[113170.535, 1]       0.013    0.009    6106.0    3729.0
# log10_anomaly_norm[113170.535, 2]       0.001    0.001    2466.0    3212.0
# log10_anomaly_norm[113191.325, 0]       0.011    0.014    8393.0    4139.0
# log10_anomaly_norm[113191.325, 1]       0.010    0.008    7989.0    3554.0
# log10_anomaly_norm[113191.325, 2]       0.001    0.001    2947.0    3268.0
# log10_anomaly_norm[113488.142, 0]       0.001    0.001    4107.0    3904.0
# log10_anomaly_norm[113488.142, 1]       0.019    0.014    3269.0    3535.0
# log10_anomaly_norm[113488.142, 2]       0.011    0.014    7456.0    4413.0
# log10_anomaly_norm[113490.985, 0]       0.011    0.015    7800.0    3718.0
# log10_anomaly_norm[113490.985, 1]       0.007    0.005    2837.0    3228.0
# log10_anomaly_norm[113490.985, 2]       0.001    0.001    2177.0    2645.0
# log10_anomaly_norm[113499.643, 0]       0.002    0.002    3705.0    3062.0
# log10_anomaly_norm[113499.643, 1]       0.012    0.008    8085.0    3582.0
# log10_anomaly_norm[113499.643, 2]       0.017    0.016    6189.0    3264.0
# log10_anomaly_norm[113508.934, 0]       0.011    0.015    8713.0    4006.0
# log10_anomaly_norm[113508.934, 1]       0.010    0.009    9833.0    3666.0
# log10_anomaly_norm[113508.934, 2]       0.001    0.001    3093.0    3762.0
# log10_anomaly_norm[113520.4215, 0]      0.012    0.014   10416.0    3489.0
# log10_anomaly_norm[113520.4215, 1]      0.010    0.016   11149.0    3528.0
# log10_anomaly_norm[113520.4215, 2]      0.012    0.013    9226.0    3700.0
# fwhm_nonthermal_norm[0]                 0.001    0.001    3752.0    3608.0
# fwhm_nonthermal_norm[1]                 0.004    0.003    3925.0    3528.0
# fwhm_nonthermal_norm[2]                 0.001    0.000    3194.0    3699.0
# fwhm_L_norm                             0.001    0.000    1890.0    2324.0
# velocity[0]                             0.000    0.000    8967.0    4067.0
# velocity[1]                             0.002    0.001    4035.0    3850.0
# velocity[2]                             0.000    0.000    3722.0    3187.0
# fwhm_thermal[0]                         0.000    0.000    5000.0    5000.0
# fwhm_thermal[1]                         0.000    0.000    5000.0    5000.0
# fwhm_thermal[2]                         0.000    0.000    5000.0    5000.0
# fwhm_nonthermal[0]                      0.001    0.001    3752.0    3608.0
# fwhm_nonthermal[1]                      0.004    0.003    3925.0    3528.0
# fwhm_nonthermal[2]                      0.001    0.000    3194.0    3699.0
# fwhm[0]                                 0.001    0.001    3752.0    3608.0
# fwhm[1]                                 0.004    0.003    3925.0    3528.0
# fwhm[2]                                 0.001    0.000    3194.0    3699.0
# fwhm_L                                  0.001    0.000    1890.0    2324.0
# log10_anomaly[113123.3687, 0]           0.000    0.000    5774.0    3774.0
# log10_anomaly[113123.3687, 1]           0.001    0.002   11088.0    3436.0
# log10_anomaly[113123.3687, 2]           0.001    0.001   11224.0    3954.0
# log10_anomaly[113144.19, 0]             0.001    0.001    8560.0    4122.0
# log10_anomaly[113144.19, 1]             0.001    0.001   10018.0    3812.0
# log10_anomaly[113144.19, 2]             0.000    0.000    3170.0    3961.0
# log10_anomaly[113170.535, 0]            0.001    0.001    8239.0    3755.0
# log10_anomaly[113170.535, 1]            0.001    0.001    6106.0    3729.0
# log10_anomaly[113170.535, 2]            0.000    0.000    2466.0    3212.0
# log10_anomaly[113191.325, 0]            0.001    0.001    8393.0    4139.0
# log10_anomaly[113191.325, 1]            0.001    0.001    7989.0    3554.0
# log10_anomaly[113191.325, 2]            0.000    0.000    2947.0    3268.0
# log10_anomaly[113488.142, 0]            0.000    0.000    4107.0    3904.0
# log10_anomaly[113488.142, 1]            0.002    0.001    3269.0    3535.0
# log10_anomaly[113488.142, 2]            0.001    0.001    7456.0    4413.0
# log10_anomaly[113490.985, 0]            0.001    0.002    7800.0    3718.0
# log10_anomaly[113490.985, 1]            0.001    0.000    2837.0    3228.0
# log10_anomaly[113490.985, 2]            0.000    0.000    2177.0    2645.0
# log10_anomaly[113499.643, 0]            0.000    0.000    3705.0    3062.0
# log10_anomaly[113499.643, 1]            0.001    0.001    8085.0    3582.0
# log10_anomaly[113499.643, 2]            0.002    0.002    6189.0    3264.0
# log10_anomaly[113508.934, 0]            0.001    0.001    8713.0    4006.0
# log10_anomaly[113508.934, 1]            0.001    0.001    9833.0    3666.0
# log10_anomaly[113508.934, 2]            0.000    0.000    3093.0    3762.0
# log10_anomaly[113520.4215, 0]           0.001    0.001   10416.0    3489.0
# log10_anomaly[113520.4215, 1]           0.001    0.002   11149.0    3528.0
# log10_anomaly[113520.4215, 2]           0.001    0.001    9226.0    3700.0
# Tex[113123.3687, 0]                     1.895    1.340    5774.0    3774.0
# Tex[113123.3687, 1]                     0.082    0.067   11088.0    3436.0
# Tex[113123.3687, 2]                     0.078    0.063   11224.0    3954.0
# Tex[113144.19, 0]                       0.094    0.076    8560.0    4122.0
# Tex[113144.19, 1]                       0.100    0.075   10018.0    3812.0
# Tex[113144.19, 2]                       0.405    0.287    3170.0    3961.0
# Tex[113170.535, 0]                      0.141    0.118    8239.0    3755.0
# Tex[113170.535, 1]                      0.170    0.122    6106.0    3729.0
# Tex[113170.535, 2]                      0.582    0.412    2466.0    3212.0
# Tex[113191.325, 0]                      0.091    0.070    8393.0    4139.0
# Tex[113191.325, 1]                      0.118    0.088    7989.0    3554.0
# Tex[113191.325, 2]                      0.371    0.262    2947.0    3268.0
# Tex[113488.142, 0]                      0.298    0.211    4107.0    3904.0
# Tex[113488.142, 1]                      0.250    0.181    3269.0    3535.0
# Tex[113488.142, 2]                      0.085    0.063    7456.0    4413.0
# Tex[113490.985, 0]                      0.085    0.065    7800.0    3718.0
# Tex[113490.985, 1]                      0.162    0.115    2837.0    3228.0
# Tex[113490.985, 2]                      0.333    0.236    2177.0    2645.0
# Tex[113499.643, 0]                      0.423    0.299    3705.0    3062.0
# Tex[113499.643, 1]                      0.138    0.102    8085.0    3582.0
# Tex[113499.643, 2]                      0.243    0.199    6189.0    3264.0
# Tex[113508.934, 0]                      0.096    0.075    8713.0    4006.0
# Tex[113508.934, 1]                      0.092    0.070    9833.0    3666.0
# Tex[113508.934, 2]                      0.465    0.329    3093.0    3762.0
# Tex[113520.4215, 0]                     0.154    0.131   10416.0    3489.0
# Tex[113520.4215, 1]                     0.083    0.067   11149.0    3528.0
# Tex[113520.4215, 2]                     0.139    0.112    9226.0    3700.0
#
#                                     r_hat
# baseline_12CN-1/2_norm[0]            1.00
# baseline_12CN-3/2_norm[0]            1.00
# velocity_norm[0]                     1.00
# velocity_norm[1]                     1.00
# velocity_norm[2]                     1.00
# log10_anomaly_norm[113123.3687, 0]   1.00
# log10_anomaly_norm[113123.3687, 1]   1.00
# log10_anomaly_norm[113123.3687, 2]   1.01
# log10_anomaly_norm[113144.19, 0]     1.00
# log10_anomaly_norm[113144.19, 1]     1.00
# log10_anomaly_norm[113144.19, 2]     1.00
# log10_anomaly_norm[113170.535, 0]    1.00
# log10_anomaly_norm[113170.535, 1]    1.00
# log10_anomaly_norm[113170.535, 2]    1.00
# log10_anomaly_norm[113191.325, 0]    1.00
# log10_anomaly_norm[113191.325, 1]    1.00
# log10_anomaly_norm[113191.325, 2]    1.00
# log10_anomaly_norm[113488.142, 0]    1.00
# log10_anomaly_norm[113488.142, 1]    1.00
# log10_anomaly_norm[113488.142, 2]    1.00
# log10_anomaly_norm[113490.985, 0]    1.00
# log10_anomaly_norm[113490.985, 1]    1.00
# log10_anomaly_norm[113490.985, 2]    1.00
# log10_anomaly_norm[113499.643, 0]    1.00
# log10_anomaly_norm[113499.643, 1]    1.00
# log10_anomaly_norm[113499.643, 2]    1.00
# log10_anomaly_norm[113508.934, 0]    1.00
# log10_anomaly_norm[113508.934, 1]    1.00
# log10_anomaly_norm[113508.934, 2]    1.00
# log10_anomaly_norm[113520.4215, 0]   1.00
# log10_anomaly_norm[113520.4215, 1]   1.00
# log10_anomaly_norm[113520.4215, 2]   1.00
# fwhm_nonthermal_norm[0]              1.00
# fwhm_nonthermal_norm[1]              1.00
# fwhm_nonthermal_norm[2]              1.00
# fwhm_L_norm                          1.00
# velocity[0]                          1.00
# velocity[1]                          1.00
# velocity[2]                          1.00
# fwhm_thermal[0]                       NaN
# fwhm_thermal[1]                       NaN
# fwhm_thermal[2]                       NaN
# fwhm_nonthermal[0]                   1.00
# fwhm_nonthermal[1]                   1.00
# fwhm_nonthermal[2]                   1.00
# fwhm[0]                              1.00
# fwhm[1]                              1.00
# fwhm[2]                              1.00
# fwhm_L                               1.00
# log10_anomaly[113123.3687, 0]        1.00
# log10_anomaly[113123.3687, 1]        1.00
# log10_anomaly[113123.3687, 2]        1.01
# log10_anomaly[113144.19, 0]          1.00
# log10_anomaly[113144.19, 1]          1.00
# log10_anomaly[113144.19, 2]          1.00
# log10_anomaly[113170.535, 0]         1.00
# log10_anomaly[113170.535, 1]         1.00
# log10_anomaly[113170.535, 2]         1.00
# log10_anomaly[113191.325, 0]         1.00
# log10_anomaly[113191.325, 1]         1.00
# log10_anomaly[113191.325, 2]         1.00
# log10_anomaly[113488.142, 0]         1.00
# log10_anomaly[113488.142, 1]         1.00
# log10_anomaly[113488.142, 2]         1.00
# log10_anomaly[113490.985, 0]         1.00
# log10_anomaly[113490.985, 1]         1.00
# log10_anomaly[113490.985, 2]         1.00
# log10_anomaly[113499.643, 0]         1.00
# log10_anomaly[113499.643, 1]         1.00
# log10_anomaly[113499.643, 2]         1.00
# log10_anomaly[113508.934, 0]         1.00
# log10_anomaly[113508.934, 1]         1.00
# log10_anomaly[113508.934, 2]         1.00
# log10_anomaly[113520.4215, 0]        1.00
# log10_anomaly[113520.4215, 1]        1.00
# log10_anomaly[113520.4215, 2]        1.00
# Tex[113123.3687, 0]                  1.00
# Tex[113123.3687, 1]                  1.00
# Tex[113123.3687, 2]                  1.01
# Tex[113144.19, 0]                    1.00
# Tex[113144.19, 1]                    1.00
# Tex[113144.19, 2]                    1.00
# Tex[113170.535, 0]                   1.00
# Tex[113170.535, 1]                   1.00
# Tex[113170.535, 2]                   1.00
# Tex[113191.325, 0]                   1.00
# Tex[113191.325, 1]                   1.00
# Tex[113191.325, 2]                   1.00
# Tex[113488.142, 0]                   1.00
# Tex[113488.142, 1]                   1.00
# Tex[113488.142, 2]                   1.00
# Tex[113490.985, 0]                   1.00
# Tex[113490.985, 1]                   1.00
# Tex[113490.985, 2]                   1.00
# Tex[113499.643, 0]                   1.00
# Tex[113499.643, 1]                   1.00
# Tex[113499.643, 2]                   1.00
# Tex[113508.934, 0]                   1.00
# Tex[113508.934, 1]                   1.00
# Tex[113508.934, 2]                   1.00
# Tex[113520.4215, 0]                  1.00
# Tex[113520.4215, 1]                  1.00
# Tex[113520.4215, 2]                  1.00

# %% [markdown]
# ## MCMC

# %%
from bayes_cn_hfs import CNRatioAnomalyIRAMModel

# Initialize and define the model
n_clouds = 3
baseline_degree = 0
model = CNRatioAnomalyIRAMModel(
    data,
    bg_temp = 2.7, # assumed background temperature (K)
    Beff=0.78, # Main beam efficiency
    Feff=0.94, # Forward efficiency
    n_clouds=n_clouds,
    baseline_degree=baseline_degree,
    seed=1234,
    verbose=True
)
model.add_priors(
    prior_log10_N_12CN = [14.0, 1.0], # mean and width of log10(12CN N) prior (cm-2)
    prior_log10_tex = [1.0, 0.1], # mean and width of log10(Tex) prior (K)
    prior_fwhm = 1.0, # width of FWHM prior (km/s)
    prior_velocity = [10.0, 10.0], # mean and width of velocity prior (km/s)
    prior_ratio_13C_12C = 0.01, # width of the 13C/12C prior
    prior_log10_tex_12CN_anomaly = 0.1, # width of 12CN Tex anomaly (K)
    ordered = False, # do not assume optically-thin
)
model.add_likelihood()

# %%
from bayes_spec.plots import plot_predictive

# prior predictive check
prior = model.sample_prior_predictive(
    samples=100,  # prior predictive samples
)
_ = plot_predictive(model.data, prior.prior_predictive)

# %%
start = time.time()
model.sample(
    init = "advi+adapt_diag", # initialization strategy
    tune = 1000, # tuning samples
    draws = 1000, # posterior samples
    chains = 8, # number of independent chains
    cores = 8, # number of parallel chains
    init_kwargs = {"rel_tolerance": 0.01, "abs_tolerance": 0.1, "learning_rate": 1e-2}, # VI initialization arguments
    nuts_kwargs = {"target_accept": 0.9}, # NUTS arguments
)
end = time.time()
print(f"Runtime: {(end-start)/60.0:.2f} minutes")
