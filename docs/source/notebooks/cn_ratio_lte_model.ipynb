# %% [markdown]
# # `CNRatioLTEModel` Tutorial
#
# Trey V. Wenger (c) December 2024
#
# Here we demonstrate the basic features of the `CNRatioLTEModel` model. The `CNRatioLTEModel` models the hyperfine spectral structure of 12CN and 13CN spectra in order to determine the physical conditions of the emitting gas, including the 12C/13C isotopic ratio. This notebook demonstrates this model and is otherwise nearly identical to the `HFSLTEModel` notebook.

# %%
# General imports
import os
import pickle
import time

import matplotlib.pyplot as plt
import arviz as az
import pandas as pd
import numpy as np
import pymc as pm

import bayes_spec
print("bayes_spec version:", bayes_spec.__version__)

import bayes_cn_hfs
print("bayes_cn_hfs version:", bayes_cn_hfs.__version__)

# Notebook configuration
pd.options.display.max_rows = None
# Out:
# bayes_spec version: 1.7.2
# bayes_cn_hfs version: 1.0.2+2.g3f0e12d.dirty

# %% [markdown]
# ## Simulating Data
#
# To test the model, we must simulate some data. We can do this with `CNRatioLTEModel`, but we must pack a "dummy" data structure first. The model expects the observation names to include the strings `"12CN"` and `"13CN"`. Multiple spectra can be passed for each, for example if there are multiple spectral windows covering one of the transitions. In this example, we only have one spectral window covering a subset of the transitions of each.

# %%
from bayes_spec import SpecData

# spectral axis definitions
freq_axis_12CN = np.arange(113470, 113530, 0.2) # MHz
freq_axis_13CN = np.arange(108750, 108820, 0.2)
print(len(freq_axis_12CN))
print(len(freq_axis_13CN))

# data noise can either be a scalar (assumed constant noise across the spectrum)
# or an array of the same length as the data
noise_12CN = 0.01 # K
noise_13CN = 0.001 # K

# brightness data. In this case, we just throw in some random data for now
# since we are only doing this in order to simulate some actual data.
brightness_data_12CN = noise_12CN * np.random.randn(len(freq_axis_12CN)) # K
brightness_data_13CN = noise_13CN * np.random.randn(len(freq_axis_13CN)) # K

# Our model only expects two observations named "12CN" and "13CN"
observation_12CN = SpecData(
    freq_axis_12CN,
    brightness_data_12CN,
    noise_12CN,
    xlabel="LSRK Frequency (MHz)",
    ylabel=r"$T_{B,\,\rm CN}$ (K)",
)
observation_13CN = SpecData(
    freq_axis_13CN,
    brightness_data_13CN,
    noise_13CN,
    xlabel="LSRK Frequency (MHz)",
    ylabel=r"$T_{B,\,^{13}\rm CN}$ (K)",
)
dummy_data = {"12CN": observation_12CN, "13CN": observation_13CN}

# Plot the dummy data
fig, axes = plt.subplots(2, layout="constrained")
axes[0].plot(dummy_data["12CN"].spectral, dummy_data["12CN"].brightness, 'k-')
axes[1].plot(dummy_data["13CN"].spectral, dummy_data["13CN"].brightness, 'k-')
axes[0].set_xlabel(dummy_data["12CN"].xlabel)
axes[1].set_xlabel(dummy_data["13CN"].xlabel)
axes[0].set_ylabel(dummy_data["12CN"].ylabel)
_ = axes[1].set_ylabel(dummy_data["13CN"].ylabel)
# Out:
# 300
# 350

# %%
from bayes_cn_hfs import CNRatioLTEModel

# Initialize and define the model
n_clouds = 3
baseline_degree = 0
model = CNRatioLTEModel(
    dummy_data,
    bg_temp = 2.7, # assumed background temperature (K)
    Beff = 1.0, # beam efficiency
    Feff = 1.0, # forward efficiency
    n_clouds=n_clouds,
    baseline_degree=baseline_degree,
    seed=1234,
    verbose=True
)
model.add_priors(
    prior_tau_total_12CN = 1.0, # width of total optical depth prior
    prior_log10_Tkin = [1.5, 0.2], # mean and width of log10(Tkin) prior (K)
    prior_velocity = [0.0, 3.0], # mean and width of velocity prior (km/s)
    prior_fwhm_nonthermal = 1.0, # width of non-thermal FWHM prior (km/s)
    prior_fwhm_L = 1.0, # width of latent Lorentzian FWHM prior (km/s)
    prior_rms = None, # do not infer spectral rms
    prior_baseline_coeffs = None, # default baseline priors
    fix_tau_total_12CN = None, # do not assume tau_total
    fix_log10_Tkin = None, # do not assume Tkin
    ordered = False, # do not assume optically-thin
)
model.add_likelihood()

sim_params = {
    "tau_total_12CN": [1.0, 2.0, 0.5],
    "log10_Tkin": [1.5, 1.25, 1.75],
    "velocity": [-3.0, 0.0, 3.0],
    "fwhm_nonthermal": [0.25, 0.5, 0.75],
    "fwhm_L": 0.0,
}
sim_params_12CN = sim_params.copy()
sim_params_12CN.update({
    "baseline_12CN_norm": [-1.0], # normalized baseline coefficients
})
sim_params_13CN = sim_params.copy()
sim_params_13CN.update({
    "ratio_13C_12C": [0.01, 0.02, 0.005],
    "baseline_13CN_norm": [2.0], # normalized baseline coefficients
})

sim_brightness_12CN = model.model["12CN"].eval(sim_params_12CN)
sim_brightness_13CN = model.model["13CN"].eval(sim_params_13CN)

# Plot the dummy data
fig, axes = plt.subplots(2, layout="constrained")
axes[0].plot(dummy_data["12CN"].spectral, sim_brightness_12CN, 'k-')
axes[1].plot(dummy_data["13CN"].spectral, sim_brightness_13CN, 'k-')
axes[0].set_xlabel(dummy_data["12CN"].xlabel)
axes[1].set_xlabel(dummy_data["13CN"].xlabel)
axes[0].set_ylabel(dummy_data["12CN"].ylabel)
_ = axes[1].set_ylabel(dummy_data["13CN"].ylabel)

# %%
# Now we pack the simulated spectra into a new SpecData instance
observation_12CN = SpecData(
    freq_axis_12CN,
    sim_brightness_12CN,
    noise_12CN,
    xlabel=r"LSRK Frequency (MHz)",
    ylabel=r"$T_{B,\,\rm CN}$ (K)",
)
observation_13CN = SpecData(
    freq_axis_13CN,
    sim_brightness_13CN,
    noise_13CN,
    xlabel=r"LSRK Frequency (MHz)",
    ylabel=r"$T_{B,\,^{13}\rm CN}$ (K)",
)
data = {"12CN": observation_12CN, "13CN": observation_13CN}

# %% [markdown]
# ## Model Definition
#
# Note that since we only care to infer the carbon isotopic ratio, and generally speaking non-thermal broadening and/or poor spectral resolution limits our ability to constrain the kinetic temperature of the gas, we can simplify the model (and break the degeneracies) by simply assuming a kinetic temperature for all clouds. The relative optical depths between the CN and 13CN components are not affected, so we are still able to constrain the isotopic ratio with this simpler model. The relative optical depths between cloud components is, however, lost.

# %%
# Initialize and define the model
model = CNRatioLTEModel(
    data,
    bg_temp = 2.7, # assumed background temperature (K)
    Beff = 1.0, # beam efficiency
    Feff = 1.0, # forward efficiency
    n_clouds=n_clouds,
    baseline_degree=baseline_degree,
    seed=1234,
    verbose=True
)
model.add_priors(
    prior_tau_total_12CN = 1.0, # width of total optical depth prior
    prior_velocity = [0.0, 3.0], # mean and width of velocity prior (km/s)
    prior_fwhm_nonthermal = 1.0, # width of non-thermal FWHM prior (km/s)
    prior_fwhm_L = 1.0, # width of latent Lorentzian FWHM prior (km/s)
    prior_rms = None, # do not infer spectral rms
    prior_baseline_coeffs = None, # default baseline priors
    fix_tau_total_12CN = None, # do not assume tau_total
    fix_log10_Tkin = 1.5, # fix log10_Tkin (K)
    ordered = False, # do not assume optically-thin
)
model.add_likelihood()

# %%
# Plot model graph
model.graph().render('cn_ratio_lte_model', format='png')
model.graph()

# %%
# model string representation
print(model.model.str_repr())
# Out:
#   baseline_12CN_norm ~ Normal(0, 1)
#   baseline_13CN_norm ~ Normal(0, 1)
#  tau_total_12CN_norm ~ HalfNormal(0, 1)
#        velocity_norm ~ Normal(0, 1)
# fwhm_nonthermal_norm ~ HalfNormal(0, 1)
#          fwhm_L_norm ~ HalfNormal(0, 1)
#   ratio_13C_12C_norm ~ Gamma(2, f())
#       tau_total_12CN ~ Deterministic(f(tau_total_12CN_norm))
#             velocity ~ Deterministic(f(velocity_norm))
#    fwhm_thermal_12CN ~ Deterministic(f())
#    fwhm_thermal_13CN ~ Deterministic(f())
#      fwhm_nonthermal ~ Deterministic(f(fwhm_nonthermal_norm))
#            fwhm_12CN ~ Deterministic(f(fwhm_nonthermal_norm))
#            fwhm_13CN ~ Deterministic(f(fwhm_nonthermal_norm))
#               fwhm_L ~ Deterministic(f(fwhm_L_norm))
#        ratio_13C_12C ~ Deterministic(f(ratio_13C_12C_norm))
#       tau_total_13CN ~ Deterministic(f(ratio_13C_12C_norm, tau_total_12CN_norm))
#             Tex_12CN ~ Deterministic(f())
#             Tex_13CN ~ Deterministic(f())
#                 12CN ~ Normal(f(baseline_12CN_norm, tau_total_12CN_norm, fwhm_L_norm, velocity_norm, fwhm_nonthermal_norm), <constant>)
#                 13CN ~ Normal(f(baseline_13CN_norm, ratio_13C_12C_norm, tau_total_12CN_norm, fwhm_L_norm, velocity_norm, fwhm_nonthermal_norm), <constant>)

# %%
from bayes_spec.plots import plot_predictive

# prior predictive check
prior = model.sample_prior_predictive(
    samples=100,  # prior predictive samples
)
_ = plot_predictive(model.data, prior.prior_predictive)
# Out:
# Sampling: [12CN, 13CN, baseline_12CN_norm, baseline_13CN_norm, fwhm_L_norm, fwhm_nonthermal_norm, ratio_13C_12C_norm, tau_total_12CN_norm, velocity_norm]

# %% [markdown]
# ## Variational Inference

# %%
start = time.time()
model.fit(
    n = 100_000, # maximum number of VI iterations
    draws = 1_000, # number of posterior samples
    rel_tolerance = 0.01, # VI relative convergence threshold
    abs_tolerance = 0.1, # VI absolute convergence threshold
    learning_rate = 1e-2, # VI learning rate
)
end = time.time()
print(f"Runtime: {(end-start)/60.0:.2f} minutes")
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Convergence achieved at 6200
# Interrupted at 6,199 [6%]: Average Loss = 2.289e+05
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Runtime: 1.55 minutes

# %%
# posterior samples stored in model.trace.posterior
pm.summary(model.trace.posterior, var_names=model.cloud_deterministics)
# Out:
# arviz - WARNING - Shape validation failed: input_shape: (1, 1000), minimum_shape: (chains=2, draws=4)
#                             mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_s
 1]   31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108638.212, 2]   31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108643.59, 0]    31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108643.59, 1]    31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108643.59, 2]    31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108644.3602, 0]  31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108644.3602, 1]  31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108644.3602, 2]  31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108645.064, 0]   31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108645.064, 1]   31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108645.064, 2]   31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108651.297, 0]   31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108651.297, 1]   31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108651.297, 2]   31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108657.646, 0]   31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108657.646, 1]   31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108657.646, 2]   31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108658.948, 0]   31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108658.948, 1]   31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108658.948, 2]   31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108780.201, 0]   31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108780.201, 1]   31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108780.201, 2]   31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108782.374, 0]   31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108782.374, 1]   31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108782.374, 2]   31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108786.982, 0]   31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108786.982, 1]   31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108786.982, 2]   31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108793.753, 0]   31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108793.753, 1]   31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108793.753, 2]   31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108796.4, 0]     31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108796.4, 1]     31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108796.4, 2]     31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108807.8006, 0]  31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108807.8006, 1]  31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108807.8006, 2]  31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108986.8678, 0]  31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108986.8678, 1]  31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[108986.8678, 2]  31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[109217.6017, 0]  31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[109217.6017, 1]  31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[109217.6017, 2]  31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[109218.3621, 0]  31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[109218.3621, 1]  31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[109218.3621, 2]  31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[109218.9506, 0]  31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[109218.9506, 1]  31.623  0.000  31.623   31.623        0.0      0.0
# Tex_13CN[109218.9506, 2]  31.623  0.000  31.623   31.623        0.0      0.0
#
#                           ess_bulk  ess_tail  r_hat
# tau_total_12CN[0]            971.0     956.0    NaN
# tau_total_12CN[1]            958.0     939.0    NaN
# tau_total_12CN[2]           1006.0     973.0    NaN
# velocity[0]                 1010.0     945.0    NaN
# velocity[1]                  923.0     981.0    NaN
# velocity[2]                  953.0     916.0    NaN
# fwhm_thermal_12CN[0]        1000.0    1000.0    NaN
# fwhm_thermal_12CN[1]        1000.0    1000.0    NaN
# fwhm_thermal_12CN[2]        1000.0    1000.0    NaN
# fwhm_thermal_13CN[0]        1000.0    1000.0    NaN
# fwhm_thermal_13CN[1]        1000.0    1000.0    NaN
# fwhm_thermal_13CN[2]        1000.0    1000.0    NaN
# fwhm_nonthermal[0]          1078.0     890.0    NaN
# fwhm_nonthermal[1]          1172.0    1073.0    NaN
# fwhm_nonthermal[2]           939.0     948.0    NaN
# fwhm_12CN[0]                1078.0     890.0    NaN
# fwhm_12CN[1]                1172.0    1073.0    NaN
# fwhm_12CN[2]                 939.0     948.0    NaN
# fwhm_13CN[0]                1078.0     890.0    NaN
# fwhm_13CN[1]                1172.0    1073.0    NaN
# fwhm_13CN[2]                 939.0     948.0    NaN
# ratio_13C_12C[0]            1104.0    1026.0    NaN
# ratio_13C_12C[1]            1051.0     940.0    NaN
# ratio_13C_12C[2]            1064.0     857.0    NaN
# tau_total_13CN[0]           1100.0    1025.0    NaN
# tau_total_13CN[1]           1050.0    1007.0    NaN
# tau_total_13CN[2]           1065.0     904.0    NaN
# Tex_12CN[113123.3687, 0]    1000.0    1000.0    NaN
# Tex_12CN[113123.3687, 1]    1000.0    1000.0    NaN
# Tex_12CN[113123.3687, 2]    1000.0    1000.0    NaN
# Tex_12CN[113144.19, 0]      1000.0    1000.0    NaN
# Tex_12CN[113144.19, 1]      1000.0    1000.0    NaN
# Tex_12CN[113144.19, 2]      1000.0    1000.0    NaN
# Tex_12CN[113170.535, 0]     1000.0    1000.0    NaN
# Tex_12CN[113170.535, 1]     1000.0    1000.0    NaN
# Tex_12CN[113170.535, 2]     1000.0    1000.0    NaN
# Tex_12CN[113191.325, 0]     1000.0    1000.0    NaN
# Tex_12CN[113191.325, 1]     1000.0    1000.0    NaN
# Tex_12CN[113191.325, 2]     1000.0    1000.0    NaN
# Tex_12CN[113488.142, 0]     1000.0    1000.0    NaN
# Tex_12CN[113488.142, 1]     1000.0    1000.0    NaN
# Tex_12CN[113488.142, 2]     1000.0    1000.0    NaN
# Tex_12CN[113490.985, 0]     1000.0    1000.0    NaN
# Tex_12CN[113490.985, 1]     1000.0    1000.0    NaN
# Tex_12CN[113490.985, 2]     1000.0    1000.0    NaN
# Tex_12CN[113499.643, 0]     1000.0    1000.0    NaN
# Tex_12CN[113499.643, 1]     1000.0    1000.0    NaN
# Tex_12CN[113499.643, 2]     1000.0    1000.0    NaN
# Tex_12CN[113508.934, 0]     1000.0    1000.0    NaN
# Tex_12CN[113508.934, 1]     1000.0    1000.0    NaN
# Tex_12CN[113508.934, 2]     1000.0    1000.0    NaN
# Tex_12CN[113520.4215, 0]    1000.0    1000.0    NaN
# Tex_12CN[113520.4215, 1]    1000.0    1000.0    NaN
# Tex_12CN[113520.4215, 2]    1000.0    1000.0    NaN
# Tex_13CN[108056.1506, 0]    1000.0    1000.0    NaN
# Tex_13CN[108056.1506, 1]    1000.0    1000.0    NaN
# Tex_13CN[108056.1506, 2]    1000.0    1000.0    NaN
# Tex_13CN[108057.1294, 0]    1000.0    1000.0    NaN
# Tex_13CN[108057.1294, 1]    1000.0    1000.0    NaN
# Tex_13CN[108057.1294, 2]    1000.0    1000.0    NaN
# Tex_13CN[108062.9185, 0]    1000.0    1000.0    NaN
# Tex_13CN[108062.9185, 1]    1000.0    1000.0    NaN
# Tex_13CN[108062.9185, 2]    1000.0    1000.0    NaN
# Tex_13CN[108076.9565, 0]    1000.0    1000.0    NaN
# Tex_13CN[108076.9565, 1]    1000.0    1000.0    NaN
# Tex_13CN[108076.9565, 2]    1000.0    1000.0    NaN
# Tex_13CN[108077.2715, 0]    1000.0    1000.0    NaN
# Tex_13CN[108077.2715, 1]    1000.0    1000.0    NaN
# Tex_13CN[108077.2715, 2]    1000.0    1000.0    NaN
# Tex_13CN[108091.3095, 0]    1000.0    1000.0    NaN
# Tex_13CN[108091.3095, 1]    1000.0    1000.0    NaN
# Tex_13CN[108091.3095, 2]    1000.0    1000.0    NaN
# Tex_13CN[108406.0979, 0]    1000.0    1000.0    NaN
# Tex_13CN[108406.0979, 1]    1000.0    1000.0    NaN
# Tex_13CN[108406.0979, 2]    1000.0    1000.0    NaN
# Tex_13CN[108412.862, 0]     1000.0    1000.0    NaN
# Tex_13CN[108412.862, 1]     1000.0    1000.0    NaN
# Tex_13CN[108412.862, 2]     1000.0    1000.0    NaN
# Tex_13CN[108426.889, 0]     1000.0    1000.0    NaN
# Tex_13CN[108426.889, 1]     1000.0    1000.0    NaN
# Tex_13CN[108426.889, 2]     1000.0    1000.0    NaN
# Tex_13CN[108631.121, 0]     1000.0    1000.0    NaN
# Tex_13CN[108631.121, 1]     1000.0    1000.0    NaN
# Tex_13CN[108631.121, 2]     1000.0    1000.0    NaN
# Tex_13CN[108636.923, 0]     1000.0    1000.0    NaN
# Tex_13CN[108636.923, 1]     1000.0    1000.0    NaN
# Tex_13CN[108636.923, 2]     1000.0    1000.0    NaN
# Tex_13CN[108638.212, 0]     1000.0    1000.0    NaN
# Tex_13CN[108638.212, 1]     1000.0    1000.0    NaN
# Tex_13CN[108638.212, 2]     1000.0    1000.0    NaN
# Tex_13CN[108643.59, 0]      1000.0    1000.0    NaN
# Tex_13CN[108643.59, 1]      1000.0    1000.0    NaN
# Tex_13CN[108643.59, 2]      1000.0    1000.0    NaN
# Tex_13CN[108644.3602, 0]    1000.0    1000.0    NaN
# Tex_13CN[108644.3602, 1]    1000.0    1000.0    NaN
# Tex_13CN[108644.3602, 2]    1000.0    1000.0    NaN
# Tex_13CN[108645.064, 0]     1000.0    1000.0    NaN
# Tex_13CN[108645.064, 1]     1000.0    1000.0    NaN
# Tex_13CN[108645.064, 2]     1000.0    1000.0    NaN
# Tex_13CN[108651.297, 0]     1000.0    1000.0    NaN
# Tex_13CN[108651.297, 1]     1000.0    1000.0    NaN
# Tex_13CN[108651.297, 2]     1000.0    1000.0    NaN
# Tex_13CN[108657.646, 0]     1000.0    1000.0    NaN
# Tex_13CN[108657.646, 1]     1000.0    1000.0    NaN
# Tex_13CN[108657.646, 2]     1000.0    1000.0    NaN
# Tex_13CN[108658.948, 0]     1000.0    1000.0    NaN
# Tex_13CN[108658.948, 1]     1000.0    1000.0    NaN
# Tex_13CN[108658.948, 2]     1000.0    1000.0    NaN
# Tex_13CN[108780.201, 0]     1000.0    1000.0    NaN
# Tex_13CN[108780.201, 1]     1000.0    1000.0    NaN
# Tex_13CN[108780.201, 2]     1000.0    1000.0    NaN
# Tex_13CN[108782.374, 0]     1000.0    1000.0    NaN
# Tex_13CN[108782.374, 1]     1000.0    1000.0    NaN
# Tex_13CN[108782.374, 2]     1000.0    1000.0    NaN
# Tex_13CN[108786.982, 0]     1000.0    1000.0    NaN
# Tex_13CN[108786.982, 1]     1000.0    1000.0    NaN
# Tex_13CN[108786.982, 2]     1000.0    1000.0    NaN
# Tex_13CN[108793.753, 0]     1000.0    1000.0    NaN
# Tex_13CN[108793.753, 1]     1000.0    1000.0    NaN
# Tex_13CN[108793.753, 2]     1000.0    1000.0    NaN
# Tex_13CN[108796.4, 0]       1000.0    1000.0    NaN
# Tex_13CN[108796.4, 1]       1000.0    1000.0    NaN
# Tex_13CN[108796.4, 2]       1000.0    1000.0    NaN
# Tex_13CN[108807.8006, 0]    1000.0    1000.0    NaN
# Tex_13CN[108807.8006, 1]    1000.0    1000.0    NaN
# Tex_13CN[108807.8006, 2]    1000.0    1000.0    NaN
# Tex_13CN[108986.8678, 0]    1000.0    1000.0    NaN
# Tex_13CN[108986.8678, 1]    1000.0    1000.0    NaN
# Tex_13CN[108986.8678, 2]    1000.0    1000.0    NaN
# Tex_13CN[109217.6017, 0]    1000.0    1000.0    NaN
# Tex_13CN[109217.6017, 1]    1000.0    1000.0    NaN
# Tex_13CN[109217.6017, 2]    1000.0    1000.0    NaN
# Tex_13CN[109218.3621, 0]    1000.0    1000.0    NaN
# Tex_13CN[109218.3621, 1]    1000.0    1000.0    NaN
# Tex_13CN[109218.3621, 2]    1000.0    1000.0    NaN
# Tex_13CN[109218.9506, 0]    1000.0    1000.0    NaN
# Tex_13CN[109218.9506, 1]    1000.0    1000.0    NaN
# Tex_13CN[109218.9506, 2]    1000.0    1000.0    NaN

# %%
posterior = model.sample_posterior_predictive(
    thin=100, # keep one in {thin} posterior samples
)
_ = plot_predictive(model.data, posterior.posterior_predictive)
# Out:
# Sampling: [12CN, 13CN]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ## MCMC

# %%
start = time.time()
model.sample(
    init = "advi+adapt_diag", # initialization strategy
    tune = 1000, # tuning samples
    draws = 1000, # posterior samples
    chains = 8, # number of independent chains
    cores = 8, # number of parallel chains
    init_kwargs = {"rel_tolerance": 0.01, "abs_tolerance": 0.1, "learning_rate": 1e-2}, # VI initialization arguments
    nuts_kwargs = {"target_accept": 0.9}, # NUTS arguments
)
end = time.time()
print(f"Runtime: {(end-start)/60.0:.2f} minutes")
# Out:
# Initializing NUTS using custom advi+adapt_diag strategy
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Convergence achieved at 6200
# Interrupted at 6,199 [6%]: Average Loss = 2.289e+05
# Multiprocess sampling (8 chains in 8 jobs)
# NUTS: [baseline_12CN_norm, baseline_13CN_norm, tau_total_12CN_norm, velocity_norm, fwhm_nonthermal_norm, fwhm_L_norm, ratio_13C_12C_norm]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 8 chains for 1_000 tune and 1_000 draw iterations (8_000 + 8_000 draws total) took 287 seconds.
# Adding log-likelihood to trace
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Runtime: 7.05 minutes

# %%
model.solve(kl_div_threshold=0.1)
# Out:
# GMM converged to unique solution

# %%
pm.summary(model.trace.solution_0, var_names=model.cloud_deterministics)
# Out:
# /var/lib/condor/execute/slot1/dir_3869349/.local/lib/python3.12/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /var/lib/condor/execute/slot1/dir_3869349/.local/lib/python3.12/site-packages/arviz/stats/diagnostics.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
#                             mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# tau_total_12CN[0]          0.958  0.002   0.954    0.962        0.0      0.0
# tau_total_12CN[1]          0.955  0.002   0.951    0.959        0.0      0.0
# tau_total_12CN[2]          1.004  0.002   1.000    1.008        0.0      0.0
# velocity[0]                3.001  0.001   2.999    3.003        0.0      0.0
# velocity[1]                0.001  0.001  -0.001    0.002        0.0      0.0
# velocity[2]               -3.000  0.000  -3.001   -3.000        0.0      0.0
# fwhm_thermal_12CN[0]       0.236  0.000   0.236    0.236        0.0      0.0
# fwhm_thermal_12CN[1]       0.236  0.000   0.236    0.236        0.0      0.0
# fwhm_thermal_12CN[2]       0.236  0.000   0.236    0.236        0.0      0.0
# fwhm_thermal_13CN[0]       0.232  0.000   0.232    0.232        0.0      0.0
# fwhm_thermal_13CN[1]       0.232  0.000   0.232    0.232        0.0      0.0
# fwhm_thermal_13CN[2]       0.232  0.000   0.232    0.232        0.0      0.0
# fwhm_nonthermal[0]         0.771  0.003   0.766    0.776        0.0      0.0
# fwhm_nonthermal[1]         0.507  0.002   0.504    0.511        0.0      0.0
# fwhm_nonthermal[2]         0.252  0.004   0.244    0.260        0.0      0.0
# fwhm_12CN[0]               0.806  0.003   0.801    0.811        0.0      0.0
# fwhm_12CN[1]               0.560  0.002   0.556    0.563        0.0      0.0
# fwhm_thermal_12CN[1]        8000.0    8000.0    NaN
# fwhm_thermal_12CN[2]        8000.0    8000.0    NaN
# fwhm_thermal_13CN[0]        8000.0    8000.0    NaN
# fwhm_thermal_13CN[1]        8000.0    8000.0    NaN
# fwhm_thermal_13CN[2]        8000.0    8000.0    NaN
# fwhm_nonthermal[0]          8405.0    5964.0    1.0
# fwhm_nonthermal[1]          7926.0    6276.0    1.0
# fwhm_nonthermal[2]          6939.0    5294.0    1.0
# fwhm_12CN[0]                8405.0    5964.0    1.0
# fwhm_12CN[1]                7926.0    6276.0    1.0
# fwhm_12CN[2]                6939.0    5294.0    1.0
# fwhm_13CN[0]                8405.0    5964.0    1.0
# fwhm_13CN[1]                7926.0    6276.0    1.0
# fwhm_13CN[2]                6939.0    5294.0    1.0
# ratio_13C_12C[0]            8549.0    5041.0    1.0
# ratio_13C_12C[1]           12577.0    6269.0    1.0
# ratio_13C_12C[2]            8567.0    6280.0    1.0
# tau_total_13CN[0]           8513.0    5067.0    1.0
# tau_total_13CN[1]          12547.0    6452.0    1.0
# tau_total_13CN[2]           8584.0    6328.0    1.0
# Tex_12CN[113123.3687, 0]    8000.0    8000.0    NaN
# Tex_12CN[113123.3687, 1]    8000.0    8000.0    NaN
# Tex_12CN[113123.3687, 2]    8000.0    8000.0    NaN
# Tex_12CN[113144.19, 0]      8000.0    8000.0    NaN
# Tex_12CN[113144.19, 1]      8000.0    8000.0    NaN
# Tex_12CN[113144.19, 2]      8000.0    8000.0    NaN
# Tex_12CN[113170.535, 0]     8000.0    8000.0    NaN
# Tex_12CN[113170.535, 1]     8000.0    8000.0    NaN
# Tex_12CN[113170.535, 2]     8000.0    8000.0    NaN
# Tex_12CN[113191.325, 0]     8000.0    8000.0    NaN
# Tex_12CN[113191.325, 1]     8000.0    8000.0    NaN
# Tex_12CN[113191.325, 2]     8000.0    8000.0    NaN
# Tex_12CN[113488.142, 0]     8000.0    8000.0    NaN
# Tex_12CN[113488.142, 1]     8000.0    8000.0    NaN
# Tex_12CN[113488.142, 2]     8000.0    8000.0    NaN
# Tex_12CN[113490.985, 0]     8000.0    8000.0    NaN
# Tex_12CN[113490.985, 1]     8000.0    8000.0    NaN
# Tex_12CN[113490.985, 2]     8000.0    8000.0    NaN
# Tex_12CN[113499.643, 0]     8000.0    8000.0    NaN
# Tex_12CN[113499.643, 1]     8000.0    8000.0    NaN
# Tex_12CN[113499.643, 2]     8000.0    8000.0    NaN
# Tex_12CN[113508.934, 0]     8000.0    8000.0    NaN
# Tex_12CN[113508.934, 1]     8000.0    8000.0    NaN
# Tex_12CN[113508.934, 2]     8000.0    8000.0    NaN
# Tex_12CN[113520.4215, 0]    8000.0    8000.0    NaN
# Tex_12CN[113520.4215, 1]    8000.0    8000.0    NaN
# Tex_12CN[113520.4215, 2]    8000.0    8000.0    NaN
# Tex_13CN[108056.1506, 0]    8000.0    8000.0    NaN
# Tex_13CN[108056.1506, 1]    8000.0    8000.0    NaN
# Tex_13CN[108056.1506, 2]    8000.0    8000.0    NaN
# Tex_13CN[108057.1294, 0]    8000.0    8000.0    NaN
# Tex_13CN[108057.1294, 1]    8000.0    8000.0    NaN
# Tex_13CN[108057.1294, 2]    8000.0    8000.0    NaN
# Tex_13CN[108062.9185, 0]    8000.0    8000.0    NaN
# Tex_13CN[108062.9185, 1]    8000.0    8000.0    NaN
# Tex_13CN[108062.9185, 2]    8000.0    8000.0    NaN
# Tex_13CN[108076.9565, 0]    8000.0    8000.0    NaN
# Tex_13CN[108076.9565, 1]    8000.0    8000.0    NaN
# Tex_13CN[108076.9565, 2]    8000.0    8000.0    NaN
# Tex_13CN[108077.2715, 0]    8000.0    8000.0    NaN
# Tex_13CN[108077.2715, 1]    8000.0    8000.0    NaN
# Tex_13CN[108077.2715, 2]    8000.0    8000.0    NaN
# Tex_13CN[108091.3095, 0]    8000.0    8000.0    NaN
# Tex_13CN[108091.3095, 1]    8000.0    8000.0    NaN
# Tex_13CN[108091.3095, 2]    8000.0    8000.0    NaN
# Tex_13CN[108406.0979, 0]    8000.0    8000.0    NaN
# Tex_13CN[108406.0979, 1]    8000.0    8000.0    NaN
# Tex_13CN[108406.0979, 2]    8000.0    8000.0    NaN
# Tex_13CN[108412.862, 0]     8000.0    8000.0    NaN
# Tex_13CN[108412.862, 1]     8000.0    8000.0    NaN
# Tex_13CN[108412.862, 2]     8000.0    8000.0    NaN
# Tex_13CN[108426.889, 0]     8000.0    8000.0    NaN
# Tex_13CN[108426.889, 1]     8000.0    8000.0    NaN
# Tex_13CN[108426.889, 2]     8000.0    8000.0    NaN
# Tex_13CN[108631.121, 0]     8000.0    8000.0    NaN
# Tex_13CN[108631.121, 1]     8000.0    8000.0    NaN
# Tex_13CN[108631.121, 2]     8000.0    8000.0    NaN
# Tex_13CN[108636.923, 0]     8000.0    8000.0    NaN
# Tex_13CN[108636.923, 1]     8000.0    8000.0    NaN
# Tex_13CN[108636.923, 2]     8000.0    8000.0    NaN
# Tex_13CN[108638.212, 0]     8000.0    8000.0    NaN
# Tex_13CN[108638.212, 1]     8000.0    8000.0    NaN
# Tex_13CN[108638.212, 2]     8000.0    8000.0    NaN
# Tex_13CN[108643.59, 0]      8000.0    8000.0    NaN
# Tex_13CN[108643.59, 1]      8000.0    8000.0    NaN
# Tex_13CN[108643.59, 2]      8000.0    8000.0    NaN
# Tex_13CN[108644.3602, 0]    8000.0    8000.0    NaN
# Tex_13CN[108644.3602, 1]    8000.0    8000.0    NaN
# Tex_13CN[108644.3602, 2]    8000.0    8000.0    NaN
# Tex_13CN[108645.064, 0]     8000.0    8000.0    NaN
# Tex_13CN[108645.064, 1]     8000.0    8000.0    NaN
# Tex_13CN[108645.064, 2]     8000.0    8000.0    NaN
# Tex_13CN[108651.297, 0]     8000.0    8000.0    NaN
# Tex_13CN[108651.297, 1]     8000.0    8000.0    NaN
# Tex_13CN[108651.297, 2]     8000.0    8000.0    NaN
# Tex_13CN[108657.646, 0]     8000.0    8000.0    NaN
# Tex_13CN[108657.646, 1]     8000.0    8000.0    NaN
# Tex_13CN[108657.646, 2]     8000.0    8000.0    NaN
# Tex_13CN[108658.948, 0]     8000.0    8000.0    NaN
# Tex_13CN[108658.948, 1]     8000.0    8000.0    NaN
# Tex_13CN[108658.948, 2]     8000.0    8000.0    NaN
# Tex_13CN[108780.201, 0]     8000.0    8000.0    NaN
# Tex_13CN[108780.201, 1]     8000.0    8000.0    NaN
# Tex_13CN[108780.201, 2]     8000.0    8000.0    NaN
# Tex_13CN[108782.374, 0]     8000.0    8000.0    NaN
# Tex_13CN[108782.374, 1]     8000.0    8000.0    NaN
# Tex_13CN[108782.374, 2]     8000.0    8000.0    NaN
# Tex_13CN[108786.982, 0]     8000.0    8000.0    NaN
# Tex_13CN[108786.982, 1]     8000.0    8000.0    NaN
# Tex_13CN[108786.982, 2]     8000.0    8000.0    NaN
# Tex_13CN[108793.753, 0]     8000.0    8000.0    NaN
# Tex_13CN[108793.753, 1]     8000.0    8000.0    NaN
# Tex_13CN[108793.753, 2]     8000.0    8000.0    NaN
# Tex_13CN[108796.4, 0]       8000.0    8000.0    NaN
# Tex_13CN[108796.4, 1]       8000.0    8000.0    NaN
# Tex_13CN[108796.4, 2]       8000.0    8000.0    NaN
# Tex_13CN[108807.8006, 0]    8000.0    8000.0    NaN
# Tex_13CN[108807.8006, 1]    8000.0    8000.0    NaN
# Tex_13CN[108807.8006, 2]    8000.0    8000.0    NaN
# Tex_13CN[108986.8678, 0]    8000.0    8000.0    NaN
# Tex_13CN[108986.8678, 1]    8000.0    8000.0    NaN
# Tex_13CN[108986.8678, 2]    8000.0    8000.0    NaN
# Tex_13CN[109217.6017, 0]    8000.0    8000.0    NaN
# Tex_13CN[109217.6017, 1]    8000.0    8000.0    NaN
# Tex_13CN[109217.6017, 2]    8000.0    8000.0    NaN
# Tex_13CN[109218.3621, 0]    8000.0    8000.0    NaN
# Tex_13CN[109218.3621, 1]    8000.0    8000.0    NaN
# Tex_13CN[109218.3621, 2]    8000.0    8000.0    NaN
# Tex_13CN[109218.9506, 0]    8000.0    8000.0    NaN
# Tex_13CN[109218.9506, 1]    8000.0    8000.0    NaN
# Tex_13CN[109218.9506, 2]    8000.0    8000.0    NaN

# %%
posterior = model.sample_posterior_predictive(
    thin=100, # keep one in {thin} posterior samples
)
_ = plot_predictive(model.data, posterior.posterior_predictive)
# Out:
# Sampling: [12CN, 13CN]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
from bayes_spec.plots import plot_traces

_ = plot_traces(model.trace.solution_0, model.cloud_freeRVs + model.baseline_freeRVs + model.hyper_freeRVs)

# %%
from bayes_spec.plots import plot_pair

var_names = [
    param for param in model.cloud_deterministics if param not in 
    ["Tex_12CN", "Tex_13CN", "fwhm_thermal_12CN", "fwhm_thermal_13CN"]
]
_ = plot_pair(
    model.trace.solution_0, # samples
    var_names, # var_names to plot
    labeller=model.labeller, # label manager
)

# %%
from bayes_spec.plots import plot_pair

_ = plot_pair(
    model.trace.solution_0.sel(cloud=1), # samples
    var_names, # var_names to plot
    labeller=model.labeller, # label manager
)

# %%
point_stats = az.summary(model.trace.solution_0, var_names=model.cloud_deterministics, kind='stats', hdi_prob=0.68)
print("BIC:", model.bic())
display(point_stats)
# Out:
# BIC: -5225.344109123951
#                             mean     sd  hdi_16%  hdi_84%
# tau_total_12CN[0]          0.958  0.002    0.956    0.960
# tau_total_12CN[1]          0.955  0.002    0.953    0.957
# tau_total_12CN[2]          1.004  0.002    1.002    1.006
# velocity[0]                3.001  0.001    3.000    3.002
# velocity[1]                0.001  0.001   -0.000    0.001
# velocity[2]               -3.000  0.000   -3.001   -3.000
# fwhm_thermal_12CN[0]       0.236  0.000    0.236    0.236
# fwhm_thermal_12CN[1]       0.236  0.000    0.236    0.236
# fwhm_thermal_12CN[2]       0.236  0.000    0.236    0.236
# fwhm_thermal_13CN[0]       0.232  0.000    0.232    0.232
# fwhm_thermal_13CN[1]       0.232  0.000    0.232    0.232
# fwhm_thermal_13CN[2]       0.232  0.000    0.232    0.232
# fwhm_nonthermal[0]         0.771  0.003    0.768    0.773
# fwhm_nonthermal[1]         0.507  0.002    0.505    0.509
# fwhm_nonthermal[2]         0.252  0.004    0.248    0.256
# fwhm_12CN[0]               0.806  0.003    0.803    0.808
# fwhm_12CN[1]               0.560  0.002    0.558    0.561
# fwhm_12CN[2]               0.345  0.003    0.342    0.348
# fwhm_13CN[0]               0.805  0.003    0.802    0.807
# fwhm_13CN[1]               0.558  0.002    0.556    0.560
# fwhm_13CN[2]               0.342  0.003    0.339    0.345
# ratio_13C_12C[0]           0.005  0.000    0.005    0.005
# ratio_13C_12C[1]           0.022  0.000    0.022    0.022
# ratio_13C_12C[2]           0.010  0.000    0.009    0.010
# tau_total_13CN[0]          0.005  0.000    0.005    0.005
# tau_total_13CN[1]          0.021  0.000    0.021    0.021
# tau_total_13CN[2]          0.010  0.000    0.010    0.010
# Tex_12CN[113123.3687, 0]  31.623  0.000   31.623   31.623
# Tex_12CN[113123.3687, 1]  31.623  0.000   31.623   31.623
# Tex_12CN[113123.3687, 2]  31.623  0.000   31.623   31.623
# Tex_12CN[113144.19, 0]    31.623  0.000   31.623   31.623
# Tex_12CN[113144.19, 1]    31.623  0.000   31.623   31.623
# Tex_12CN[113144.19, 2]    31.623  0.000   31.623   31.623
# Tex_12CN[113170.535, 0]   31.623  0.000   31.623   31.623
# Tex_12CN[113170.535, 1]   31.623  0.000   31.623   31.623
# Tex_12CN[113170.535, 2]   31.623  0.000   31.623   31.623
# Tex_12CN[113191.325, 0]   31.623  0.000   31.623   31.623
# Tex_12CN[113191.325, 1]   31.623  0.000   31.623   31.623
# Tex_12CN[113191.325, 2]   31.623  0.000   31.623   31.623
# Tex_12CN[113488.142, 0]   31.623  0.000   31.623   31.623
# Tex_12CN[113488.142, 1]   31.623  0.000   31.623   31.623
# Tex_12CN[113488.142, 2]   31.623  0.000   31.623   31.623
# Tex_12CN[113490.985, 0]   31.623  0.000   31.623   31.623
# Tex_12CN[113490.985, 1]   31.623  0.000   31.623   31.623
# Tex_12CN[113490.985, 2]   31.623  0.000   31.623   31.623
# Tex_12CN[113499.643, 0]   31.623  0.000   31.623   31.623
# Tex_12CN[113499.643, 1]   31.623  0.000   31.623   31.623
# Tex_12CN[113499.643, 2]   31.623  0.000   31.623   31.623
